# %%
import pickle
cache_file = 'TQQQ_stock_cache.pkl'
with open(cache_file, 'rb') as fi:
    data = pickle.load(fi)
data.keys()
# Out:
# dict_keys(['TQQQ', '^VIX', 'DX-Y.NYB'])

# %%
#*-* coding: utf-8 *-*
#!/usr/bin/env python3

#https://algotrading101.com/learn/backtrader-for-backtesting/
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])
import backtrader as bt
import backtrader.indicators as btind
from backtrader.feeds import GenericCSVData

import itertools
import backtrader as bt
import pandas as pd
import quantstats


class MLSignal(bt.Indicator):

    lines = ('predict',)

    def __init__(self):
        self.lines.predict = self.data0.predict

class MLPredictCsv(bt.feeds.PandasData):
    '''
    Desc: for customized CSV format
    '''

    # What new data will be availible in the Stratagies line object
    lines = ('predict',)

    # Which columns go to which variable
    params = (
        ('open', 'open'),
        ('high', 'high'),
        ('low', 'low'),
        ('close', 'close'),
        ('Adj Close','Adj Close'),
        ('volume', 'volume'),
        ('openinterest', 'openinterest'),
        ('predict', 'predict'),
    )

# Create a Stratey
class MLStrategy(bt.Strategy):
    params = (
    )
    
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.dataopen = self.datas[0].open
        self.ml_signal = MLSignal(self.data)
        self.buysig = self.datas[0].predict #btind.CrossOver(sma_fast, sma_slow)
        # To keep track of pending orders
        self.order = None

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def next(self):
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:
            # Buy
            if self.ml_signal.lines.predict == bt.SIGNAL_LONG:#
                self.log('BUY CREATE, %.2f' % self.dataclose[0])
                self.order = self.buy()
        else:
            #Sel
            if self.ml_signal.lines.predict == bt.SIGNAL_SHORT:# and len(self) >= (self.bar_executed + 3):
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

def strategyEvaluate(tick_symbol, ml_predict_csv, strategy_log_file, quant_output, quant_output_html, n_stake = 40, cash_capital = 1000):
    '''
    Desc: ML predict signal based strategy evaluation

    '''
    mlpredicted_signal = pd.read_csv(ml_predict_csv,
                                parse_dates=True,
                                index_col=0,                             
                            )
    def mapsignal(x):
        if x == 0:
            return bt.SIGNAL_NONE
        elif x == 1:
            return bt.SIGNAL_LONG
        elif x == 2:
            return bt.SIGNAL_SHORT
    
    mlpredicted_signal['predict'] = mlpredicted_signal['predict'].transform(mapsignal)

    yr1, mth1, day1 = list(map(lambda x:int(x),str(mlpredicted_signal.index[0]).split(' ')[0].split('-')))
    yr2, mth2, day2 = list(map(lambda x:int(x),str(mlpredicted_signal.index[-1]).split(' ')[0].split('-')))
    
    mlpredicted_signal['openinterest'] = 0
    data = MLPredictCsv(dataname=mlpredicted_signal)

    # create Cerebro instance and attach data to it
    cerebro = bt.Cerebro()
    cerebro.adddata(data)
    # Add a strategy
    cerebro.addstrategy(MLStrategy)

    # cerebro.add_signal(bt.SIGNAL_LONGSHORT, MLSignal)

    #Add strategy to Cerebro
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe_ratio')
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='PyFolio')

    # better net liquidation value view
    cerebro.addobserver(bt.observers.Value)

    # Default position size
    cerebro.addsizer(bt.sizers.SizerFix, stake=n_stake)    
    
    #add output log file 
    cerebro.addwriter(bt.WriterFile, csv=True, out=strategy_log_file)    

    # Set our desired cash start
    cerebro.broker.setcash(cash_capital)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    results = cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    #Get strategy stats
    strat = results[0]
    portfolio_stats = strat.analyzers.getbyname('PyFolio')
    returns, positions, transactions, gross_lev = portfolio_stats.get_pf_items()
    returns.index = returns.index.tz_convert(None)
    
    # print(returns)
    # print(positions)
    # print(portfolio_stats)
    quantstats.reports.html(returns, output = quant_output, download_filename = quant_output_html, title = tick_symbol)
    
    import webbrowser
    webbrowser.open(quant_output_html)

    cerebro.plot(iplot=False)

if __name__ == '__main__':
    tick_symbol = 'TQQQ'
    signal_file = f'datas/{tick_symbol}_predict_eval.csv'
    o_strategy_log_file = f'datas/{tick_symbol}_predict_eval_strategy.log'
    o_quant_output_file = f'datas/{tick_symbol}_predict_eval_strategy.stats'
    o_quant_output_html = f'datas/{tick_symbol}_predict_eval_strategy.html'
    n_stake = 10

    strategyEvaluate(tick_symbol, signal_file, o_strategy_log_file, o_quant_output_file, o_quant_output_html, n_stake)
# Out:
# Starting Portfolio Value: 1000.00
# 2020-04-01, BUY CREATE, 10.43
# 2020-04-02, BUY EXECUTED, 10.30
# 2020-04-07, SELL CREATE, 12.80
# 2020-04-08, SELL EXECUTED, 13.17
# 2020-04-08, BUY CREATE, 13.62
# 2020-04-09, BUY EXECUTED, 13.98
# 2020-04-13, SELL CREATE, 14.14
# 2020-04-14, SELL EXECUTED, 15.01
# 2020-04-17, BUY CREATE, 16.68
# 2020-04-20, BUY EXECUTED, 16.30
# 2020-04-20, SELL CREATE, 16.14
# 2020-04-21, SELL EXECUTED, 15.66
# 2020-04-21, BUY CREATE, 14.36
# 2020-04-22, BUY EXECUTED, 15.26
# 2020-04-22, SELL CREATE, 15.63
# 2020-04-23, SELL EXECUTED, 15.81
# 2020-04-24, BUY CREATE, 16.27
# 2020-04-27, BUY EXECUTED, 16.80
# 2020-04-29, SELL CREATE, 17.33
# 2020-04-30, SELL EXECUTED, 17.60
# 2020-05-06, BUY CREATE, 17.30
# 2020-05-07, BUY EXECUTED, 17.96
# 2020-05-11, SELL CREATE, 19.16
# 2020-05-12, SELL EXECUTED, 19.37
# 2020-05-18, BUY CREATE, 19.28
# 2020-05-19, BUY EXECUTED, 19.34
# 2020-05-19, SELL CREATE, 19.13
# 2020-05-20, SELL EXECUTED, 19.80
# 2020-06-16, BUY CREATE, 23.11
# 2020-06-17, BUY EXECUTED, 23.54
# 2020-06-22, SELL CREATE, 24.32
# 2020-06-23, SELL EXECUTED, 24.84
# 2020-06-26, BUY CREATE, 22.37
# 2020-06-29, BUY EXECUTED, 22.30
# 2020-07-07, SELL CREATE, 27.17
# 2020-07-08, SELL EXECUTED, 27.61
# 2020-07-13, BUY CREATE, 27.71
# 2020-07-14, BUY EXECUTED, 26.90
# 2020-07-14, SELL CREATE, 28.30
# 2020-07-15, SELL EXECUTED, 28.72
# 2020-07-23, BUY CREATE, 27.38
# 2020-07-24, BUY EXECUTED, 26.13
# 2020-07-24, SELL CREATE, 26.57
# 2020-07-27, SELL EXECUTED, 27.15
# 2020-07-28, BUY CREATE, 26.95
# 2020-07-29, BUY EXECUTED, 27.42
# 2020-07-31, SELL CREATE, 29.84
# 2020-08-03, SELL EXECUTED, 30.56
# 2020-08-19, BUY CREATE, 33.24
# 2020-08-20, BUY EXECUTED, 32.94
# 2020-08-20, SELL CREATE, 34.61
# 2020-08-21, SELL EXECUTED, 34.67
# 2020-08-24, BUY CREATE, 35.99
# 2020-08-25, BUY EXECUTED, 35.71
# 2020-08-26, SELL CREATE, 39.18
# 2020-08-27, SELL EXECUTED, 39.65
# 2020-09-03, BUY CREATE, 36.93
# 2020-09-04, BUY EXECUTED, 36.35
# 2020-09-04, SELL CREATE, 35.41
# 2020-09-08, SELL EXECUTED, 31.24
# 2020-09-10, BUY CREATE, 31.11
# 2020-09-11, BUY EXECUTED, 31.75
# 2020-09-14, SELL CREATE, 32.00
# 2020-09-15, SELL EXECUTED, 33.33
# 2020-09-15, BUY CREATE, 33.35
# 2020-09-16, BUY EXECUTED, 33.63
# 2020-09-17, SELL CREATE, 30.29
# 2020-09-18, SELL EXECUTED, 30.72
# 2020-09-22, BUY CREATE, 31.08
# 2020-09-23, BUY EXECUTED, 30.96
# 2020-10-02, SELL CREATE, 31.43
# 2020-10-05, SELL EXECUTED, 32.12
# 2020-10-06, BUY CREATE, 31.62
# 2020-10-07, BUY EXECUTED, 32.54
# 2020-10-13, SELL CREATE, 38.57
# 2020-10-14, SELL EXECUTED, 38.92
# 2020-10-14, BUY CREATE, 37.62
# 2020-10-15, BUY EXECUTED, 35.76
# 2020-10-19, SELL CREATE, 34.47
# 2020-10-20, SELL EXECUTED, 34.74
# 2020-10-20, BUY CREATE, 34.69
# 2020-10-21, BUY EXECUTED, 34.77
# 2020-10-22, SELL CREATE, 34.62
# 2020-10-23, SELL EXECUTED, 34.85
# 2020-10-23, BUY CREATE, 34.83
# 2020-10-26, BUY EXECUTED, 33.94
# 2020-10-26, SELL CREATE, 33.24
# 2020-10-27, SELL EXECUTED, 33.57
# 2020-11-02, BUY CREATE, 29.37
# 2020-11-03, BUY EXECUTED, 30.00
# 2020-11-11, SELL CREATE, 35.88
# 2020-11-12, SELL EXECUTED, 36.21
# 2020-11-12, BUY CREATE, 35.36
# 2020-11-13, BUY EXECUTED, 35.94
# 2020-11-13, SELL CREATE, 36.28
# 2020-11-16, SELL EXECUTED, 36.19
# 2020-11-23, BUY CREATE, 36.08
# 2020-11-24, BUY EXECUTED, 36.46
# 2020-12-10, SELL CREATE, 40.61
# 2020-12-11, SELL EXECUTED, 39.91
# 2020-12-11, BUY CREATE, 40.33
# 2020-12-14, BUY EXECUTED, 40.81
# 2020-12-23, SELL CREATE, 43.10
# 2020-12-24, SELL EXECUTED, 43.23
# 2021-01-04, BUY CREATE, 43.46
# 2021-01-05, BUY EXECUTED, 43.07
# 2021-01-06, SELL CREATE, 42.71
# 2021-01-07, SELL EXECUTED, 43.84
# 2021-01-07, BUY CREATE, 45.79
# 2021-01-08, BUY EXECUTED, 46.83
# 2021-01-11, SELL CREATE, 45.47
# 2021-01-12, SELL EXECUTED, 45.53
# 2021-01-12, BUY CREATE, 45.27
# 2021-01-13, BUY EXECUTED, 45.39
# 2021-01-14, SELL CREATE, 45.45
# 2021-01-15, SELL EXECUTED, 45.35
# 2021-02-17, BUY CREATE, 53.83
# 2021-02-18, BUY EXECUTED, 52.03
# 2021-02-22, SELL CREATE, 48.35
# 2021-02-23, SELL EXECUTED, 45.89
# 2021-02-26, BUY CREATE, 44.61
# 2021-03-01, BUY EXECUTED, 46.68
# 2021-03-03, SELL CREATE, 42.17
# 2021-03-04, SELL EXECUTED, 41.99
# 2021-03-08, BUY CREATE, 38.30
# 2021-03-09, BUY EXECUTED, 41.24
# 2021-03-09, SELL CREATE, 42.81
# 2021-03-10, SELL EXECUTED, 44.63
# 2021-03-10, BUY CREATE, 42.44
# 2021-03-11, BUY EXECUTED, 44.51
# 2021-03-12, SELL CREATE, 44.26
# 2021-03-15, SELL EXECUTED, 44.40
# 2021-03-19, BUY CREATE, 43.24
# 2021-03-22, BUY EXECUTED, 44.15
# 2021-03-26, SELL CREATE, 44.33
# 2021-03-29, SELL EXECUTED, 44.12
# 2021-03-29, BUY CREATE, 44.30
# 2021-03-30, BUY EXECUTED, 43.47
# 2021-04-05, SELL CREATE, 50.83
# 2021-04-06, SELL EXECUTED, 50.68
# 2021-04-20, BUY CREATE, 53.19
# 2021-04-21, BUY EXECUTED, 52.50
# 2021-04-21, SELL CREATE, 54.53
# 2021-04-22, SELL EXECUTED, 54.33
# 2021-04-27, BUY CREATE, 54.88
# 2021-04-28, BUY EXECUTED, 54.69
# 2021-04-29, SELL CREATE, 54.86
# 2021-04-30, SELL EXECUTED, 53.65
# 2021-05-05, BUY CREATE, 49.58
# 2021-05-06, BUY EXECUTED, 49.44
# 2021-05-12, SELL CREATE, 44.12
# 2021-05-13, SELL EXECUTED, 45.30
# 2021-05-17, BUY CREATE, 47.17
# 2021-05-18, BUY EXECUTED, 47.60
# 2021-05-18, SELL CREATE, 46.19
# 2021-05-19, SELL EXECUTED, 43.83
# 2021-05-21, BUY CREATE, 48.22
# 2021-05-24, BUY EXECUTED, 49.28
# 2021-05-24, SELL CREATE, 50.64
# 2021-05-25, SELL EXECUTED, 51.38
# 2021-05-25, BUY CREATE, 50.88
# 2021-05-26, BUY EXECUTED, 51.18
# 2021-05-26, SELL CREATE, 51.40
# 2021-05-27, SELL EXECUTED, 51.19
# 2021-06-08, BUY CREATE, 52.51
# 2021-06-09, BUY EXECUTED, 53.18
# 2021-06-21, SELL CREATE, 56.21
# 2021-06-22, SELL EXECUTED, 56.15
# 2021-06-29, BUY CREATE, 61.52
# 2021-06-30, BUY EXECUTED, 61.44
# 2021-07-08, SELL CREATE, 63.50
# 2021-07-09, SELL EXECUTED, 63.14
# 2021-07-15, BUY CREATE, 64.35
# 2021-07-16, BUY EXECUTED, 64.83
# 2021-08-23, SELL CREATE, 70.93
# 2021-08-24, SELL EXECUTED, 71.31
# 2021-09-16, BUY CREATE, 73.72
# 2021-09-17, BUY EXECUTED, 73.45
# 2021-09-17, SELL CREATE, 71.12
# 2021-09-20, SELL EXECUTED, 67.71
# 2021-09-21, BUY CREATE, 66.83
# 2021-09-22, BUY EXECUTED, 67.43
# 2021-09-22, SELL CREATE, 68.79
# 2021-09-23, SELL EXECUTED, 69.46
# 2021-09-23, BUY CREATE, 70.69
# 2021-09-24, BUY EXECUTED, 69.36
# 2021-10-01, SELL CREATE, 63.42
# 2021-10-04, SELL EXECUTED, 62.55
# 2021-10-07, BUY CREATE, 64.74
# 2021-10-08, BUY EXECUTED, 65.33
# 2021-10-11, SELL CREATE, 62.33
# 2021-10-12, SELL EXECUTED, 63.08
# 2021-10-12, BUY CREATE, 61.69
# 2021-10-13, BUY EXECUTED, 62.89
# 2021-10-13, SELL CREATE, 63.13
# 2021-10-14, SELL EXECUTED, 65.06
# 2021-10-14, BUY CREATE, 66.62
# 2021-10-15, BUY EXECUTED, 67.30
# 2021-10-18, SELL CREATE, 69.89
# 2021-10-19, SELL EXECUTED, 70.52
# 2021-10-26, BUY CREATE, 73.44
# 2021-10-27, BUY EXECUTED, 73.78
# 2021-11-09, SELL CREATE, 83.18
# 2021-11-10, SELL EXECUTED, 81.36
# 2021-11-11, BUY CREATE, 80.18
# 2021-11-12, BUY EXECUTED, 80.90
# 2021-11-24, SELL CREATE, 85.11
# 2021-11-26, SELL EXECUTED, 83.39
# 2021-12-01, BUY CREATE, 77.55
# 2021-12-02, BUY EXECUTED, 76.71
# 2021-12-02, SELL CREATE, 79.01
# 2021-12-03, SELL EXECUTED, 80.00
# 2021-12-03, BUY CREATE, 75.04
# 2021-12-06, BUY EXECUTED, 75.29
# 2021-12-06, SELL CREATE, 76.79
# 2021-12-07, SELL EXECUTED, 80.89
# 2021-12-07, BUY CREATE, 83.72
# 2021-12-08, BUY EXECUTED, 83.94
# 2021-12-09, SELL CREATE, 81.22
# 2021-12-10, SELL EXECUTED, 82.89
# 2021-12-13, BUY CREATE, 80.14
# 2021-12-14, BUY EXECUTED, 77.06
# 2021-12-14, SELL CREATE, 77.75
# 2021-12-15, SELL EXECUTED, 77.48
# 2021-12-16, BUY CREATE, 76.57
# 2021-12-17, BUY EXECUTED, 74.42
# 2021-12-17, SELL CREATE, 75.40
# 2021-12-20, SELL EXECUTED, 72.51
# 2021-12-20, BUY CREATE, 73.14
# 2021-12-21, BUY EXECUTED, 75.08
# 2021-12-27, SELL CREATE, 86.69
# 2021-12-28, SELL EXECUTED, 87.38
# 2021-12-31, BUY CREATE, 83.17
# 2022-01-03, BUY EXECUTED, 83.92
# 2022-01-03, SELL CREATE, 85.57
# 2022-01-04, SELL EXECUTED, 85.92
# 2022-01-06, BUY CREATE, 74.47
# 2022-01-07, BUY EXECUTED, 74.45
# 2022-01-11, SELL CREATE, 75.48
# 2022-01-12, SELL EXECUTED, 76.99
# 2022-01-13, BUY CREATE, 70.80
# 2022-01-14, BUY EXECUTED, 69.09
# 2022-01-18, SELL CREATE, 66.69
# 2022-01-19, SELL EXECUTED, 67.36
# 2022-01-24, BUY CREATE, 57.49
# 2022-01-25, BUY EXECUTED, 54.15
# 2022-02-03, SELL CREATE, 56.74
# 2022-02-04, SELL EXECUTED, 56.87
# 2022-02-07, BUY CREATE, 57.37
# 2022-02-08, BUY EXECUTED, 56.80
# 2022-02-10, SELL CREATE, 58.82
# 2022-02-11, SELL EXECUTED, 58.78
# 2022-02-14, BUY CREATE, 53.43
# 2022-02-15, BUY EXECUTED, 55.83
# 2022-02-16, SELL CREATE, 57.29
# 2022-02-17, SELL EXECUTED, 55.64
# 2022-02-23, BUY CREATE, 45.14
# 2022-02-24, BUY EXECUTED, 40.76
# 2022-02-24, SELL CREATE, 49.56
# 2022-02-25, SELL EXECUTED, 50.00
# 2022-02-25, BUY CREATE, 51.91
# 2022-02-28, BUY EXECUTED, 50.46
# 2022-03-03, SELL CREATE, 50.24
# 2022-03-04, SELL EXECUTED, 49.17
# 2022-03-07, BUY CREATE, 42.72
# 2022-03-08, BUY EXECUTED, 42.39
# 2022-03-09, SELL CREATE, 46.64
# 2022-03-10, SELL EXECUTED, 44.90
# 2022-03-11, BUY CREATE, 42.34
# 2022-03-14, BUY EXECUTED, 41.81
# 2022-03-14, SELL CREATE, 39.86
# 2022-03-15, SELL EXECUTED, 40.87
# 2022-03-16, BUY CREATE, 48.44
# 2022-03-17, BUY EXECUTED, 47.59
# 2022-03-22, SELL CREATE, 55.91
# 2022-03-23, SELL EXECUTED, 54.56
# 2022-03-31, BUY CREATE, 58.18
# 2022-04-01, BUY EXECUTED, 58.43
# 2022-04-01, SELL CREATE, 57.93
# 2022-04-04, SELL EXECUTED, 58.38
# 2022-04-05, BUY CREATE, 57.48
# 2022-04-06, BUY EXECUTED, 54.82
# 2022-04-06, SELL CREATE, 53.70
# 2022-04-07, SELL EXECUTED, 53.23
# 2022-04-25, BUY CREATE, 43.05
# 2022-04-26, BUY EXECUTED, 42.22
# 2022-04-28, SELL CREATE, 42.06
# 2022-04-29, SELL EXECUTED, 40.39
# 2022-05-03, BUY CREATE, 38.34
# 2022-05-04, BUY EXECUTED, 38.49
# 2022-05-05, SELL CREATE, 35.86
# 2022-05-06, SELL EXECUTED, 35.09
# 2022-05-06, BUY CREATE, 34.61
# 2022-05-09, BUY EXECUTED, 32.56
# 2022-05-12, SELL CREATE, 28.53
# 2022-05-13, SELL EXECUTED, 29.85
# 2022-05-16, BUY CREATE, 30.65
# 2022-05-17, BUY EXECUTED, 32.43
# 2022-05-20, SELL CREATE, 27.34
# 2022-05-23, SELL EXECUTED, 27.65
# 2022-05-23, BUY CREATE, 28.69
# 2022-05-24, BUY EXECUTED, 27.15
# 2022-05-24, SELL CREATE, 26.90
# 2022-05-25, SELL EXECUTED, 26.44
# 2022-05-25, BUY CREATE, 27.98
# 2022-05-26, BUY EXECUTED, 27.76
# 2022-05-26, SELL CREATE, 30.32
# 2022-05-27, SELL EXECUTED, 31.30
# 2022-05-31, BUY CREATE, 33.05
# 2022-06-01, BUY EXECUTED, 33.71
# 2022-06-02, SELL CREATE, 34.90
# 2022-06-03, SELL EXECUTED, 33.14
# 2022-06-03, BUY CREATE, 32.14
# 2022-06-06, BUY EXECUTED, 33.62
# 2022-06-06, SELL CREATE, 32.54
# 2022-06-07, SELL EXECUTED, 31.42
# 2022-06-08, BUY CREATE, 32.65
# 2022-06-09, BUY EXECUTED, 32.07
# 2022-06-09, SELL CREATE, 29.99
# 2022-06-10, SELL EXECUTED, 28.26
# 2022-06-16, BUY CREATE, 21.86
# 2022-06-17, BUY EXECUTED, 22.07
# 2022-06-17, SELL CREATE, 22.67
# 2022-06-21, SELL EXECUTED, 23.82
# 2022-06-21, BUY CREATE, 24.38
# 2022-06-22, BUY EXECUTED, 23.71
# 2022-06-24, SELL CREATE, 27.98
# 2022-06-27, SELL EXECUTED, 28.35
# 2022-06-27, BUY CREATE, 27.32
# 2022-06-28, BUY EXECUTED, 27.46
# 2022-06-28, SELL CREATE, 24.83
# 2022-06-29, SELL EXECUTED, 24.78
# 2022-06-29, BUY CREATE, 24.88
# 2022-06-30, BUY EXECUTED, 24.06
# 2022-06-30, SELL CREATE, 24.00
# 2022-07-01, SELL EXECUTED, 23.60
# 2022-07-01, BUY CREATE, 24.39
# 2022-07-05, BUY EXECUTED, 23.41
# 2022-07-05, SELL CREATE, 25.65
# 2022-07-06, SELL EXECUTED, 25.77
# 2022-07-06, BUY CREATE, 26.14
# 2022-07-07, BUY EXECUTED, 26.38
# 2022-07-11, SELL CREATE, 26.11
# 2022-07-12, SELL EXECUTED, 26.44
# 2022-07-15, BUY CREATE, 26.79
# 2022-07-18, BUY EXECUTED, 27.61
# 2022-07-20, SELL CREATE, 29.89
# 2022-07-21, SELL EXECUTED, 30.01
# 2022-07-21, BUY CREATE, 31.16
# 2022-07-22, BUY EXECUTED, 30.88
# 2022-07-25, SELL CREATE, 29.09
# 2022-07-26, SELL EXECUTED, 28.49
# 2022-07-26, BUY CREATE, 27.33
# 2022-07-27, BUY EXECUTED, 28.60
# 2022-07-27, SELL CREATE, 30.74
# 2022-07-28, SELL EXECUTED, 30.68
# 2022-08-02, BUY CREATE, 33.00
# 2022-08-03, BUY EXECUTED, 33.55
# 2022-08-03, SELL CREATE, 35.64
# 2022-08-04, SELL EXECUTED, 35.69
# 2022-08-09, BUY CREATE, 33.73
# 2022-08-10, BUY EXECUTED, 36.14
# 2022-08-15, SELL CREATE, 38.89
# 2022-08-16, SELL EXECUTED, 38.56
# 2022-08-16, BUY CREATE, 38.64
# 2022-08-17, BUY EXECUTED, 37.51
# 2022-08-19, SELL CREATE, 35.35
# 2022-08-22, SELL EXECUTED, 33.89
# 2022-08-23, BUY CREATE, 32.46
# 2022-08-24, BUY EXECUTED, 32.30
# 2022-08-25, SELL CREATE, 34.43
# 2022-08-26, SELL EXECUTED, 34.35
# 2022-08-29, BUY CREATE, 29.31
# 2022-08-30, BUY EXECUTED, 29.79
# 2022-09-01, SELL CREATE, 27.84
# 2022-09-02, SELL EXECUTED, 28.64
# 2022-09-02, BUY CREATE, 26.68
# 2022-09-06, BUY EXECUTED, 26.76
# 2022-09-06, SELL CREATE, 26.07
# 2022-09-07, SELL EXECUTED, 26.18
# 2022-09-08, BUY CREATE, 28.06
# 2022-09-09, BUY EXECUTED, 28.68
# 2022-09-09, SELL CREATE, 29.84
# 2022-09-12, SELL EXECUTED, 30.30
# 2022-09-12, BUY CREATE, 30.93
# 2022-09-13, BUY EXECUTED, 28.24
# 2022-09-13, SELL CREATE, 25.84
# 2022-09-14, SELL EXECUTED, 26.13
# 2022-09-15, BUY CREATE, 25.09
# 2022-09-16, BUY EXECUTED, 24.21
# 2022-09-21, SELL CREATE, 23.24
# 2022-09-22, SELL EXECUTED, 22.85
# 2022-09-23, BUY CREATE, 21.31
# 2022-09-26, BUY EXECUTED, 21.16
# 2022-09-28, SELL CREATE, 22.27
# 2022-09-29, SELL EXECUTED, 21.31
# Final Portfolio Value: 1763.75
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="300">

# %%
#*-* coding: utf-8 *-*
#!/usr/bin/env python3

'''
long-short strategy evaluation
'''
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])
import backtrader as bt
import backtrader.indicators as btind
from backtrader.feeds import GenericCSVData

import itertools
import backtrader as bt
import pandas as pd
import quantstats
from backtrader.analyzers import (SQN, AnnualReturn, TimeReturn, SharpeRatio,
                                  TradeAnalyzer)

# onlylong = False

class MLSignal(bt.Indicator):

    lines = ('predict',)

    def __init__(self):
        self.lines.predict = self.data0.predict

class MLPredictCsv(bt.feeds.PandasData):
    '''
    Desc: for customized CSV format
    '''

    # What new data will be availible in the Stratagies line object
    lines = ('predict',)

    # Which columns go to which variable
    params = (
        ('open', 'Open'),
        ('high', 'High'),
        ('low', 'Low'),
        ('close', 'Close'),
        ('Adj Close','Adj Close'),
        ('volume', 'volume'),
        ('openinterest', 'openinterest'),
        ('predict', 'signal'),
    )

# Create a Stratey
class MLStrategy(bt.Strategy):
    params = dict(
        onlylong = False
    )
    
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.dataopen = self.datas[0].open
        self.ml_signal = MLSignal(self.data)
        self.buysig = self.datas[0].predict 
        # To keep track of pending orders
        self.order = None

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def next(self):
        #if order is active, no new order allow
        if self.order:
            return

        # Check if we are in the market
        if self.buysig > 0:
            if self.position:
                self.log('CLOSE SHORT , %.2f' % self.data.close[0])
                self.close()
            # Buy
            self.log('BUY CREATE, %.2f' % self.dataclose[0])
            self.order = self.buy()
        elif self.buysig < 0:
            if self.position:
                self.log('CLOSE LONG , %.2f' % self.data.close[0])
                self.close()
            
            if not self.p.onlylong:
                self.log('SELL CREATE , %.2f' % self.data.close[0])
                self.sell()

def strategyEvaluate(tick_symbol, ml_predict_csv, strategy_log_file, quant_output, quant_output_html, n_stake = 40, cash_capital = 1000):
    '''
    Desc: ML predict signal based strategy evaluation

    '''
    mlpredicted_signal = pd.read_csv(ml_predict_csv,
                                parse_dates=True,
                                index_col=0,                             
                            )
    def mapsignal(x):
        if x == 0:
            return 0 #bt.SIGNAL_NONE
        elif x == 1:
            return 1 #bt.SIGNAL_LONG
        elif x == 2:
            return -1 #bt.SIGNAL_SHORT
    
    mlpredicted_signal['signal'] = mlpredicted_signal['signal'].transform(mapsignal)

    yr1, mth1, day1 = list(map(lambda x:int(x),str(mlpredicted_signal.index[0]).split(' ')[0].split('-')))
    yr2, mth2, day2 = list(map(lambda x:int(x),str(mlpredicted_signal.index[-1]).split(' ')[0].split('-')))
    
    mlpredicted_signal['openinterest'] = 0
    data = MLPredictCsv(dataname=mlpredicted_signal)

    # create Cerebro instance and attach data to it
    cerebro = bt.Cerebro()
    cerebro.adddata(data)
    # Add a strategy
    cerebro.addstrategy(MLStrategy, onlylong = False)
    # Set our desired cash start
    cerebro.broker.setcash(cash_capital)

#     cerebro.broker.setcommission(commission=0)

    #Add strategy to Cerebro
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe_ratio')
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='PyFolio')
    cerebro.addanalyzer(TradeAnalyzer)

    # better net liquidation value view
    cerebro.addobserver(bt.observers.Value)

    # Default position size
    cerebro.addsizer(bt.sizers.SizerFix, stake=n_stake)    
    
    #add output log file 
    cerebro.addwriter(bt.WriterFile, csv=True, out=strategy_log_file)    


    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    results = cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    #Get strategy stats
    strat = results[0]
    portfolio_stats = strat.analyzers.getbyname('PyFolio')
    returns, positions, transactions, gross_lev = portfolio_stats.get_pf_items()
    returns.index = returns.index.tz_convert(None)
    
    # print(returns)
    # print(positions)
    # print(portfolio_stats)
    quantstats.reports.html(returns, output = quant_output, download_filename = quant_output_html, title = tick_symbol)
    
    import webbrowser
    webbrowser.open(quant_output_html)

    cerebro.plot(iplot=False)

if __name__ == '__main__':
    tick_symbol = 'TQQQ'
    signal_file = f'datas/{tick_symbol}_predict_eval_test.csv'
    o_strategy_log_file = f'datas/{tick_symbol}_predict_eval_strategy.log'
    o_quant_output_file = f'datas/{tick_symbol}_predict_eval_strategy.stats'
    o_quant_output_html = f'datas/{tick_symbol}_predict_eval_strategy.html'
    n_stake = 10

    strategyEvaluate(tick_symbol, signal_file, o_strategy_log_file, o_quant_output_file, o_quant_output_html, n_stake)
# Out:
# Starting Portfolio Value: 1000.00
# 2020-04-01, BUY CREATE, 10.43
# 2020-04-02, BUY EXECUTED, 10.30
# 2020-04-02, CLOSE SHORT , 11.05
# 2020-04-02, BUY CREATE, 11.05
# 2020-04-03, SELL EXECUTED, 10.97
# 2020-04-03, BUY EXECUTED, 10.97
# 2020-04-03, CLOSE SHORT , 10.60
# 2020-04-03, BUY CREATE, 10.60
# 2020-04-06, SELL EXECUTED, 11.78
# 2020-04-06, BUY EXECUTED, 11.78
# 2020-04-06, CLOSE SHORT , 12.82
# 2020-04-06, BUY CREATE, 12.82
# 2020-04-07, SELL EXECUTED, 13.98
# 2020-04-07, BUY EXECUTED, 13.98
# 2020-04-07, CLOSE LONG , 12.80
# 2020-04-07, SELL CREATE , 12.80
# 2020-04-08, SELL EXECUTED, 13.17
# 2020-04-08, SELL EXECUTED, 13.17
# 2020-04-08, CLOSE SHORT , 13.62
# 2020-04-08, BUY CREATE, 13.62
# 2020-04-09, BUY EXECUTED, 13.98
# 2020-04-09, BUY EXECUTED, 13.98
# 2020-04-09, CLOSE SHORT , 13.67
# 2020-04-09, BUY CREATE, 13.67
# 2020-04-13, SELL EXECUTED, 13.50
# 2020-04-13, BUY EXECUTED, 13.50
# 2020-04-13, CLOSE LONG , 14.14
# 2020-04-13, SELL CREATE , 14.14
# 2020-04-14, SELL EXECUTED, 15.01
# 2020-04-14, SELL EXECUTED, 15.01
# 2020-04-14, CLOSE LONG , 15.98
# 2020-04-14, SELL CREATE , 15.98
# 2020-04-15, BUY EXECUTED, 15.23
# 2020-04-15, SELL EXECUTED, 15.23
# 2020-04-15, CLOSE LONG , 15.45
# 2020-04-15, SELL CREATE , 15.45
# 2020-04-16, BUY EXECUTED, 15.95
# 2020-04-16, SELL EXECUTED, 15.95
# 2020-04-16, CLOSE LONG , 16.27
# 2020-04-16, SELL CREATE , 16.27
# 2020-04-17, BUY EXECUTED, 16.92
# 2020-04-17, SELL EXECUTED, 16.92
# 2020-04-17, CLOSE SHORT , 16.68
# 2020-04-17, BUY CREATE, 16.68
# 2020-04-20, BUY EXECUTED, 16.30
# 2020-04-20, BUY EXECUTED, 16.30
# 2020-04-20, CLOSE LONG , 16.14
# 2020-04-20, SELL CREATE , 16.14
# 2020-04-21, SELL EXECUTED, 15.66
# 2020-04-21, SELL EXECUTED, 15.66
# 2020-04-21, CLOSE SHORT , 14.36
# 2020-04-21, BUY CREATE, 14.36
# 2020-04-22, BUY EXECUTED, 15.26
# 2020-04-22, BUY EXECUTED, 15.26
# 2020-04-22, CLOSE LONG , 15.63
# 2020-04-22, SELL CREATE , 15.63
# 2020-04-23, SELL EXECUTED, 15.81
# 2020-04-23, SELL EXECUTED, 15.81
# 2020-04-23, CLOSE LONG , 15.52
# 2020-04-23, SELL CREATE , 15.52
# 2020-04-24, BUY EXECUTED, 15.64
# 2020-04-24, SELL EXECUTED, 15.64
# 2020-04-24, CLOSE SHORT , 16.27
# 2020-04-24, BUY CREATE, 16.27
# 2020-04-27, BUY EXECUTED, 16.80
# 2020-04-27, BUY EXECUTED, 16.80
# 2020-04-29, CLOSE LONG , 17.33
# 2020-04-29, SELL CREATE , 17.33
# 2020-04-30, SELL EXECUTED, 17.60
# 2020-04-30, SELL EXECUTED, 17.60
# 2020-05-01, CLOSE LONG , 15.88
# 2020-05-01, SELL CREATE , 15.88
# 2020-05-04, BUY EXECUTED, 15.64
# 2020-05-04, SELL EXECUTED, 15.64
# 2020-05-04, CLOSE LONG , 16.44
# 2020-05-04, SELL CREATE , 16.44
# 2020-05-05, BUY EXECUTED, 16.93
# 2020-05-05, SELL EXECUTED, 16.93
# 2020-05-05, CLOSE LONG , 16.96
# 2020-05-05, SELL CREATE , 16.96
# 2020-05-06, BUY EXECUTED, 17.39
# 2020-05-06, SELL EXECUTED, 17.39
# 2020-05-06, CLOSE SHORT , 17.30
# 2020-05-06, BUY CREATE, 17.30
# 2020-05-07, BUY EXECUTED, 17.96
# 2020-05-07, BUY EXECUTED, 17.96
# 2020-05-11, CLOSE LONG , 19.16
# 2020-05-11, SELL CREATE , 19.16
# 2020-05-12, SELL EXECUTED, 19.37
# 2020-05-12, SELL EXECUTED, 19.37
# 2020-05-13, CLOSE LONG , 17.34
# 2020-05-13, SELL CREATE , 17.34
# 2020-05-14, BUY EXECUTED, 17.01
# 2020-05-14, SELL EXECUTED, 17.01
# 2020-05-14, CLOSE LONG , 17.92
# 2020-05-14, SELL CREATE , 17.92
# 2020-05-15, BUY EXECUTED, 17.18
# 2020-05-15, SELL EXECUTED, 17.18
# 2020-05-15, CLOSE LONG , 18.22
# 2020-05-15, SELL CREATE , 18.22
# 2020-05-18, BUY EXECUTED, 19.00
# 2020-05-18, SELL EXECUTED, 19.00
# 2020-05-18, CLOSE SHORT , 19.28
# 2020-05-18, BUY CREATE, 19.28
# 2020-05-19, BUY EXECUTED, 19.34
# 2020-05-19, BUY EXECUTED, 19.34
# 2020-05-19, CLOSE LONG , 19.13
# 2020-05-19, SELL CREATE , 19.13
# 2020-05-20, SELL EXECUTED, 19.80
# 2020-05-20, SELL EXECUTED, 19.80
# 2020-05-21, CLOSE LONG , 19.63
# 2020-05-21, SELL CREATE , 19.63
# 2020-05-22, BUY EXECUTED, 19.52
# 2020-05-22, SELL EXECUTED, 19.52
# 2020-05-27, CLOSE LONG , 20.00
# 2020-05-27, SELL CREATE , 20.00
# 2020-05-28, BUY EXECUTED, 19.65
# 2020-05-28, SELL EXECUTED, 19.65
# 2020-05-29, CLOSE LONG , 20.69
# 2020-05-29, SELL CREATE , 20.69
# 2020-06-01, BUY EXECUTED, 20.51
# 2020-06-01, SELL EXECUTED, 20.51
# 2020-06-08, CLOSE LONG , 22.97
# 2020-06-08, SELL CREATE , 22.97
# 2020-06-09, BUY EXECUTED, 22.72
# 2020-06-09, SELL EXECUTED, 22.72
# 2020-06-11, CLOSE LONG , 20.75
# 2020-06-11, SELL CREATE , 20.75
# 2020-06-12, BUY EXECUTED, 22.07
# 2020-06-12, SELL EXECUTED, 22.07
# 2020-06-12, CLOSE LONG , 21.20
# 2020-06-12, SELL CREATE , 21.20
# 2020-06-15, BUY EXECUTED, 20.27
# 2020-06-15, SELL EXECUTED, 20.27
# 2020-06-15, CLOSE LONG , 21.95
# 2020-06-15, SELL CREATE , 21.95
# 2020-06-16, BUY EXECUTED, 23.35
# 2020-06-16, SELL EXECUTED, 23.35
# 2020-06-16, CLOSE SHORT , 23.11
# 2020-06-16, BUY CREATE, 23.11
# 2020-06-17, BUY EXECUTED, 23.54
# 2020-06-17, BUY EXECUTED, 23.54
# 2020-06-17, CLOSE SHORT , 23.33
# 2020-06-17, BUY CREATE, 23.33
# 2020-06-18, SELL EXECUTED, 23.24
# 2020-06-18, BUY EXECUTED, 23.24
# 2020-06-19, CLOSE SHORT , 23.48
# 2020-06-19, BUY CREATE, 23.48
# 2020-06-22, SELL EXECUTED, 23.48
# 2020-06-22, BUY EXECUTED, 23.48
# 2020-06-22, CLOSE LONG , 24.32
# 2020-06-22, SELL CREATE , 24.32
# 2020-06-23, SELL EXECUTED, 24.84
# 2020-06-23, SELL EXECUTED, 24.84
# 2020-06-24, CLOSE LONG , 23.48
# 2020-06-24, SELL CREATE , 23.48
# 2020-06-25, BUY EXECUTED, 23.48
# 2020-06-25, SELL EXECUTED, 23.48
# 2020-06-25, CLOSE LONG , 24.10
# 2020-06-25, SELL CREATE , 24.10
# 2020-06-26, BUY EXECUTED, 24.00
# 2020-06-26, SELL EXECUTED, 24.00
# 2020-06-26, CLOSE SHORT , 22.37
# 2020-06-26, BUY CREATE, 22.37
# 2020-06-29, BUY EXECUTED, 22.30
# 2020-06-29, BUY EXECUTED, 22.30
# 2020-06-29, CLOSE SHORT , 23.08
# 2020-06-29, BUY CREATE, 23.08
# 2020-06-30, SELL EXECUTED, 23.08
# 2020-06-30, BUY EXECUTED, 23.08
# 2020-07-01, CLOSE SHORT , 25.28
# 2020-07-01, BUY CREATE, 25.28
# 2020-07-02, SELL EXECUTED, 26.07
# 2020-07-02, BUY EXECUTED, 26.07
# 2020-07-07, CLOSE LONG , 27.17
# 2020-07-07, SELL CREATE , 27.17
# 2020-07-08, SELL EXECUTED, 27.61
# 2020-07-08, SELL EXECUTED, 27.61
# 2020-07-09, CLOSE LONG , 28.92
# 2020-07-09, SELL CREATE , 28.92
# 2020-07-10, BUY EXECUTED, 28.85
# 2020-07-10, SELL EXECUTED, 28.85
# 2020-07-13, CLOSE SHORT , 27.71
# 2020-07-13, BUY CREATE, 27.71
# 2020-07-14, BUY EXECUTED, 26.90
# 2020-07-14, BUY EXECUTED, 26.90
# 2020-07-14, CLOSE LONG , 28.30
# 2020-07-14, SELL CREATE , 28.30
# 2020-07-15, SELL EXECUTED, 28.72
# 2020-07-15, SELL EXECUTED, 28.72
# 2020-07-21, CLOSE LONG , 29.37
# 2020-07-21, SELL CREATE , 29.37
# 2020-07-22, BUY EXECUTED, 29.54
# 2020-07-22, SELL EXECUTED, 29.54
# 2020-07-23, CLOSE SHORT , 27.38
# 2020-07-23, BUY CREATE, 27.38
# 2020-07-24, BUY EXECUTED, 26.13
# 2020-07-24, BUY EXECUTED, 26.13
# 2020-07-24, CLOSE LONG , 26.57
# 2020-07-24, SELL CREATE , 26.57
# 2020-07-27, SELL EXECUTED, 27.15
# 2020-07-27, SELL EXECUTED, 27.15
# 2020-07-27, CLOSE LONG , 28.00
# 2020-07-27, SELL CREATE , 28.00
# 2020-07-28, BUY EXECUTED, 27.77
# 2020-07-28, SELL EXECUTED, 27.77
# 2020-07-28, CLOSE SHORT , 26.95
# 2020-07-28, BUY CREATE, 26.95
# 2020-07-29, BUY EXECUTED, 27.42
# 2020-07-29, BUY EXECUTED, 27.42
# 2020-07-29, CLOSE SHORT , 27.86
# 2020-07-29, BUY CREATE, 27.86
# 2020-07-30, SELL EXECUTED, 27.23
# 2020-07-30, BUY EXECUTED, 27.23
# 2020-07-30, CLOSE SHORT , 28.32
# 2020-07-30, BUY CREATE, 28.32
# 2020-07-31, SELL EXECUTED, 29.83
# 2020-07-31, BUY EXECUTED, 29.83
# 2020-07-31, CLOSE LONG , 29.84
# 2020-07-31, SELL CREATE , 29.84
# 2020-08-03, SELL EXECUTED, 30.56
# 2020-08-03, SELL EXECUTED, 30.56
# 2020-08-10, CLOSE LONG , 31.32
# 2020-08-10, SELL CREATE , 31.32
# 2020-08-11, BUY EXECUTED, 30.89
# 2020-08-11, SELL EXECUTED, 30.89
# 2020-08-11, CLOSE LONG , 29.54
# 2020-08-11, SELL CREATE , 29.54
# 2020-08-12, BUY EXECUTED, 30.27
# 2020-08-12, SELL EXECUTED, 30.27
# 2020-08-12, CLOSE LONG , 31.75
# 2020-08-12, SELL CREATE , 31.75
# 2020-08-13, BUY EXECUTED, 32.02
# 2020-08-13, SELL EXECUTED, 32.02
# 2020-08-19, CLOSE SHORT , 33.24
# 2020-08-19, BUY CREATE, 33.24
# 2020-08-20, BUY EXECUTED, 32.94
# 2020-08-20, BUY EXECUTED, 32.94
# 2020-08-20, CLOSE LONG , 34.61
# 2020-08-20, SELL CREATE , 34.61
# 2020-08-21, SELL EXECUTED, 34.67
# 2020-08-21, SELL EXECUTED, 34.67
# 2020-08-24, CLOSE SHORT , 35.99
# 2020-08-24, BUY CREATE, 35.99
# 2020-08-25, BUY EXECUTED, 35.71
# 2020-08-25, BUY EXECUTED, 35.71
# 2020-08-26, CLOSE LONG , 39.18
# 2020-08-26, SELL CREATE , 39.18
# 2020-08-27, SELL EXECUTED, 39.65
# 2020-08-27, SELL EXECUTED, 39.65
# 2020-09-01, CLOSE LONG , 42.44
# 2020-09-01, SELL CREATE , 42.44
# 2020-09-02, BUY EXECUTED, 43.87
# 2020-09-02, SELL EXECUTED, 43.87
# 2020-09-02, CLOSE LONG , 43.63
# 2020-09-02, SELL CREATE , 43.63
# 2020-09-03, BUY EXECUTED, 41.68
# 2020-09-03, SELL EXECUTED, 41.68
# 2020-09-03, CLOSE SHORT , 36.93
# 2020-09-03, BUY CREATE, 36.93
# 2020-09-04, BUY EXECUTED, 36.35
# 2020-09-04, BUY EXECUTED, 36.35
# 2020-09-04, CLOSE LONG , 35.41
# 2020-09-04, SELL CREATE , 35.41
# 2020-09-08, SELL EXECUTED, 31.24
# 2020-09-08, SELL EXECUTED, 31.24
# 2020-09-08, CLOSE LONG , 30.41
# 2020-09-08, SELL CREATE , 30.41
# 2020-09-09, BUY EXECUTED, 32.26
# 2020-09-09, SELL EXECUTED, 32.26
# 2020-09-09, CLOSE LONG , 33.02
# 2020-09-09, SELL CREATE , 33.02
# 2020-09-10, BUY EXECUTED, 34.13
# 2020-09-10, SELL EXECUTED, 34.13
# 2020-09-10, CLOSE SHORT , 31.11
# 2020-09-10, BUY CREATE, 31.11
# 2020-09-11, BUY EXECUTED, 31.75
# 2020-09-11, BUY EXECUTED, 31.75
# 2020-09-11, CLOSE SHORT , 30.43
# 2020-09-11, BUY CREATE, 30.43
# 2020-09-14, SELL EXECUTED, 31.75
# 2020-09-14, BUY EXECUTED, 31.75
# 2020-09-14, CLOSE LONG , 32.00
# 2020-09-14, SELL CREATE , 32.00
# 2020-09-15, SELL EXECUTED, 33.33
# 2020-09-15, SELL EXECUTED, 33.33
# 2020-09-15, CLOSE SHORT , 33.35
# 2020-09-15, BUY CREATE, 33.35
# 2020-09-16, BUY EXECUTED, 33.63
# 2020-09-16, BUY EXECUTED, 33.63
# 2020-09-16, CLOSE SHORT , 31.75
# 2020-09-16, BUY CREATE, 31.75
# 2020-09-17, SELL EXECUTED, 29.30
# 2020-09-17, BUY EXECUTED, 29.30
# 2020-09-17, CLOSE LONG , 30.29
# 2020-09-17, SELL CREATE , 30.29
# 2020-09-18, SELL EXECUTED, 30.72
# 2020-09-18, SELL EXECUTED, 30.72
# 2020-09-18, CLOSE LONG , 29.12
# 2020-09-18, SELL CREATE , 29.12
# 2020-09-21, BUY EXECUTED, 27.81
# 2020-09-21, SELL EXECUTED, 27.81
# 2020-09-21, CLOSE LONG , 29.47
# 2020-09-21, SELL CREATE , 29.47
# 2020-09-22, BUY EXECUTED, 30.30
# 2020-09-22, SELL EXECUTED, 30.30
# 2020-09-22, CLOSE SHORT , 31.08
# 2020-09-22, BUY CREATE, 31.08
# 2020-09-23, BUY EXECUTED, 30.96
# 2020-09-23, BUY EXECUTED, 30.96
# 2020-09-23, CLOSE SHORT , 28.20
# 2020-09-23, BUY CREATE, 28.20
# 2020-09-24, SELL EXECUTED, 27.42
# 2020-09-24, BUY EXECUTED, 27.42
# 2020-09-24, CLOSE SHORT , 28.61
# 2020-09-24, BUY CREATE, 28.61
# 2020-09-25, SELL EXECUTED, 28.77
# 2020-09-25, BUY EXECUTED, 28.77
# 2020-09-25, CLOSE SHORT , 30.61
# 2020-09-25, BUY CREATE, 30.61
# 2020-09-28, SELL EXECUTED, 32.32
# 2020-09-28, BUY EXECUTED, 32.32
# 2020-09-28, CLOSE SHORT , 32.43
# 2020-09-28, BUY CREATE, 32.43
# 2020-09-29, SELL EXECUTED, 32.37
# 2020-09-29, BUY EXECUTED, 32.37
# 2020-09-29, CLOSE SHORT , 32.09
# 2020-09-29, BUY CREATE, 32.09
# 2020-09-30, SELL EXECUTED, 32.15
# 2020-09-30, BUY EXECUTED, 32.15
# 2020-09-30, CLOSE SHORT , 32.72
# 2020-09-30, BUY CREATE, 32.72
# 2020-10-01, SELL EXECUTED, 34.14
# 2020-10-01, BUY EXECUTED, 34.14
# 2020-10-02, CLOSE LONG , 31.43
# 2020-10-02, SELL CREATE , 31.43
# 2020-10-05, SELL EXECUTED, 32.12
# 2020-10-05, SELL EXECUTED, 32.12
# 2020-10-06, CLOSE SHORT , 31.62
# 2020-10-06, BUY CREATE, 31.62
# 2020-10-07, BUY EXECUTED, 32.54
# 2020-10-07, BUY EXECUTED, 32.54
# 2020-10-13, CLOSE LONG , 38.57
# 2020-10-13, SELL CREATE , 38.57
# 2020-10-14, SELL EXECUTED, 38.92
# 2020-10-14, SELL EXECUTED, 38.92
# 2020-10-14, CLOSE SHORT , 37.62
# 2020-10-14, BUY CREATE, 37.62
# 2020-10-15, BUY EXECUTED, 35.76
# 2020-10-15, BUY EXECUTED, 35.76
# 2020-10-15, CLOSE SHORT , 36.84
# 2020-10-15, BUY CREATE, 36.84
# 2020-10-16, SELL EXECUTED, 37.52
# 2020-10-16, BUY EXECUTED, 37.52
# 2020-10-16, CLOSE SHORT , 36.28
# 2020-10-16, BUY CREATE, 36.28
# 2020-10-19, SELL EXECUTED, 37.01
# 2020-10-19, BUY EXECUTED, 37.01
# 2020-10-19, CLOSE LONG , 34.47
# 2020-10-19, SELL CREATE , 34.47
# 2020-10-20, SELL EXECUTED, 34.74
# 2020-10-20, SELL EXECUTED, 34.74
# 2020-10-20, CLOSE SHORT , 34.69
# 2020-10-20, BUY CREATE, 34.69
# 2020-10-21, BUY EXECUTED, 34.77
# 2020-10-21, BUY EXECUTED, 34.77
# 2020-10-21, CLOSE SHORT , 34.60
# 2020-10-21, BUY CREATE, 34.60
# 2020-10-22, SELL EXECUTED, 34.92
# 2020-10-22, BUY EXECUTED, 34.92
# 2020-10-22, CLOSE LONG , 34.62
# 2020-10-22, SELL CREATE , 34.62
# 2020-10-23, SELL EXECUTED, 34.85
# 2020-10-23, SELL EXECUTED, 34.85
# 2020-10-23, CLOSE SHORT , 34.83
# 2020-10-23, BUY CREATE, 34.83
# 2020-10-26, BUY EXECUTED, 33.94
# 2020-10-26, BUY EXECUTED, 33.94
# 2020-10-26, CLOSE LONG , 33.24
# 2020-10-26, SELL CREATE , 33.24
# 2020-10-27, SELL EXECUTED, 33.57
# 2020-10-27, SELL EXECUTED, 33.57
# 2020-10-28, CLOSE LONG , 30.03
# 2020-10-28, SELL CREATE , 30.03
# 2020-10-29, BUY EXECUTED, 30.49
# 2020-10-29, SELL EXECUTED, 30.49
# 2020-10-29, CLOSE LONG , 31.56
# 2020-10-29, SELL CREATE , 31.56
# 2020-10-30, BUY EXECUTED, 30.89
# 2020-10-30, SELL EXECUTED, 30.89
# 2020-10-30, CLOSE LONG , 29.36
# 2020-10-30, SELL CREATE , 29.36
# 2020-11-02, BUY EXECUTED, 29.95
# 2020-11-02, SELL EXECUTED, 29.95
# 2020-11-02, CLOSE SHORT , 29.37
# 2020-11-02, BUY CREATE, 29.37
# 2020-11-03, BUY EXECUTED, 30.00
# 2020-11-03, BUY EXECUTED, 30.00
# 2020-11-03, CLOSE SHORT , 30.85
# 2020-11-03, BUY CREATE, 30.85
# 2020-11-04, SELL EXECUTED, 33.90
# 2020-11-04, BUY EXECUTED, 33.90
# 2020-11-04, CLOSE SHORT , 35.02
# 2020-11-04, BUY CREATE, 35.02
# 2020-11-05, SELL EXECUTED, 37.42
# 2020-11-05, BUY EXECUTED, 37.42
# 2020-11-09, CLOSE SHORT , 35.54
# 2020-11-09, BUY CREATE, 35.54
# 2020-11-10, SELL EXECUTED, 34.28
# 2020-11-10, BUY EXECUTED, 34.28
# 2020-11-10, CLOSE SHORT , 33.62
# 2020-11-10, BUY CREATE, 33.62
# 2020-11-11, SELL EXECUTED, 34.52
# 2020-11-11, BUY EXECUTED, 34.52
# 2020-11-11, CLOSE LONG , 35.88
# 2020-11-11, SELL CREATE , 35.88
# 2020-11-12, SELL EXECUTED, 36.21
# 2020-11-12, SELL EXECUTED, 36.21
# 2020-11-12, CLOSE SHORT , 35.36
# 2020-11-12, BUY CREATE, 35.36
# 2020-11-13, BUY EXECUTED, 35.94
# 2020-11-13, BUY EXECUTED, 35.94
# 2020-11-13, CLOSE LONG , 36.28
# 2020-11-13, SELL CREATE , 36.28
# 2020-11-16, SELL EXECUTED, 36.19
# 2020-11-16, SELL EXECUTED, 36.19
# 2020-11-18, CLOSE LONG , 35.92
# 2020-11-18, SELL CREATE , 35.92
# 2020-11-19, BUY EXECUTED, 35.73
# 2020-11-19, SELL EXECUTED, 35.73
# 2020-11-20, CLOSE LONG , 36.07
# 2020-11-20, SELL CREATE , 36.07
# 2020-11-23, BUY EXECUTED, 36.46
# 2020-11-23, SELL EXECUTED, 36.46
# 2020-11-23, CLOSE SHORT , 36.08
# 2020-11-23, BUY CREATE, 36.08
# 2020-11-24, BUY EXECUTED, 36.46
# 2020-11-24, BUY EXECUTED, 36.46
# 2020-12-10, CLOSE LONG , 40.61
# 2020-12-10, SELL CREATE , 40.61
# 2020-12-11, SELL EXECUTED, 39.91
# 2020-12-11, SELL EXECUTED, 39.91
# 2020-12-11, CLOSE SHORT , 40.33
# 2020-12-11, BUY CREATE, 40.33
# 2020-12-14, BUY EXECUTED, 40.81
# 2020-12-14, BUY EXECUTED, 40.81
# 2020-12-14, CLOSE SHORT , 41.19
# 2020-12-14, BUY CREATE, 41.19
# 2020-12-15, SELL EXECUTED, 42.15
# 2020-12-15, BUY EXECUTED, 42.15
# 2020-12-23, CLOSE LONG , 43.10
# 2020-12-23, SELL CREATE , 43.10
# 2020-12-24, SELL EXECUTED, 43.23
# 2020-12-24, SELL EXECUTED, 43.23
# 2021-01-04, CLOSE SHORT , 43.46
# 2021-01-04, BUY CREATE, 43.46
# 2021-01-05, BUY EXECUTED, 43.07
# 2021-01-05, BUY EXECUTED, 43.07
# 2021-01-06, CLOSE LONG , 42.71
# 2021-01-06, SELL CREATE , 42.71
# 2021-01-07, SELL EXECUTED, 43.84
# 2021-01-07, SELL EXECUTED, 43.84
# 2021-01-07, CLOSE SHORT , 45.79
# 2021-01-07, BUY CREATE, 45.79
# 2021-01-08, BUY EXECUTED, 46.83
# 2021-01-08, BUY EXECUTED, 46.83
# 2021-01-08, CLOSE SHORT , 47.57
# 2021-01-08, BUY CREATE, 47.57
# 2021-01-11, SELL EXECUTED, 46.20
# 2021-01-11, BUY EXECUTED, 46.20
# 2021-01-11, CLOSE LONG , 45.47
# 2021-01-11, SELL CREATE , 45.47
# 2021-01-12, SELL EXECUTED, 45.53
# 2021-01-12, SELL EXECUTED, 45.53
# 2021-01-12, CLOSE SHORT , 45.27
# 2021-01-12, BUY CREATE, 45.27
# 2021-01-13, BUY EXECUTED, 45.39
# 2021-01-13, BUY EXECUTED, 45.39
# 2021-01-14, CLOSE LONG , 45.45
# 2021-01-14, SELL CREATE , 45.45
# 2021-01-15, SELL EXECUTED, 45.35
# 2021-01-15, SELL EXECUTED, 45.35
# 2021-01-20, CLOSE LONG , 49.49
# 2021-01-20, SELL CREATE , 49.49
# 2021-01-21, BUY EXECUTED, 50.12
# 2021-01-21, SELL EXECUTED, 50.12
# 2021-01-27, CLOSE LONG , 47.54
# 2021-01-27, SELL CREATE , 47.54
# 2021-01-28, BUY EXECUTED, 47.94
# 2021-01-28, SELL EXECUTED, 47.94
# 2021-01-28, CLOSE LONG , 48.24
# 2021-01-28, SELL CREATE , 48.24
# 2021-01-29, BUY EXECUTED, 47.45
# 2021-01-29, SELL EXECUTED, 47.45
# 2021-01-29, CLOSE LONG , 45.24
# 2021-01-29, SELL CREATE , 45.24
# 2021-02-01, BUY EXECUTED, 46.78
# 2021-02-01, SELL EXECUTED, 46.78
# 2021-02-01, CLOSE LONG , 48.56
# 2021-02-01, SELL CREATE , 48.56
# 2021-02-02, BUY EXECUTED, 49.94
# 2021-02-02, SELL EXECUTED, 49.94
# 2021-02-10, CLOSE LONG , 53.28
# 2021-02-10, SELL CREATE , 53.28
# 2021-02-11, BUY EXECUTED, 54.08
# 2021-02-11, SELL EXECUTED, 54.08
# 2021-02-17, CLOSE SHORT , 53.83
# 2021-02-17, BUY CREATE, 53.83
# 2021-02-18, BUY EXECUTED, 52.03
# 2021-02-18, BUY EXECUTED, 52.03
# 2021-02-18, CLOSE SHORT , 53.11
# 2021-02-18, BUY CREATE, 53.11
# 2021-02-19, SELL EXECUTED, 53.82
# 2021-02-19, BUY EXECUTED, 53.82
# 2021-02-19, CLOSE SHORT , 52.41
# 2021-02-19, BUY CREATE, 52.41
# 2021-02-22, SELL EXECUTED, 50.27
# 2021-02-22, BUY EXECUTED, 50.27
# 2021-02-22, CLOSE LONG , 48.35
# 2021-02-22, SELL CREATE , 48.35
# 2021-02-23, SELL EXECUTED, 45.89
# 2021-02-23, SELL EXECUTED, 45.89
# 2021-02-23, CLOSE LONG , 47.92
# 2021-02-23, SELL CREATE , 47.92
# 2021-02-24, BUY EXECUTED, 46.62
# 2021-02-24, SELL EXECUTED, 46.62
# 2021-02-25, CLOSE LONG , 43.95
# 2021-02-25, SELL CREATE , 43.95
# 2021-02-26, BUY EXECUTED, 45.19
# 2021-02-26, SELL EXECUTED, 45.19
# 2021-02-26, CLOSE SHORT , 44.61
# 2021-02-26, BUY CREATE, 44.61
# 2021-03-01, BUY EXECUTED, 46.68
# 2021-03-01, BUY EXECUTED, 46.68
# 2021-03-01, CLOSE SHORT , 48.50
# 2021-03-01, BUY CREATE, 48.50
# 2021-03-02, SELL EXECUTED, 48.77
# 2021-03-02, BUY EXECUTED, 48.77
# 2021-03-02, CLOSE SHORT , 46.17
# 2021-03-02, BUY CREATE, 46.17
# 2021-03-03, SELL EXECUTED, 45.69
# 2021-03-03, BUY EXECUTED, 45.69
# 2021-03-03, CLOSE LONG , 42.17
# 2021-03-03, SELL CREATE , 42.17
# 2021-03-04, SELL EXECUTED, 41.99
# 2021-03-04, SELL EXECUTED, 41.99
# 2021-03-04, CLOSE LONG , 40.08
# 2021-03-04, SELL CREATE , 40.08
# 2021-03-05, BUY EXECUTED, 41.15
# 2021-03-05, SELL EXECUTED, 41.15
# 2021-03-05, CLOSE LONG , 41.88
# 2021-03-05, SELL CREATE , 41.88
# 2021-03-08, BUY EXECUTED, 41.64
# 2021-03-08, SELL EXECUTED, 41.64
# 2021-03-08, CLOSE SHORT , 38.30
# 2021-03-08, BUY CREATE, 38.30
# 2021-03-09, BUY EXECUTED, 41.24
# 2021-03-09, BUY EXECUTED, 41.24
# 2021-03-09, CLOSE LONG , 42.81
# 2021-03-09, SELL CREATE , 42.81
# 2021-03-10, SELL EXECUTED, 44.63
# 2021-03-10, SELL EXECUTED, 44.63
# 2021-03-10, CLOSE SHORT , 42.44
# 2021-03-10, BUY CREATE, 42.44
# 2021-03-11, BUY EXECUTED, 44.51
# 2021-03-11, BUY EXECUTED, 44.51
# 2021-03-11, CLOSE SHORT , 45.39
# 2021-03-11, BUY CREATE, 45.39
# 2021-03-12, SELL EXECUTED, 43.58
# 2021-03-12, BUY EXECUTED, 43.58
# 2021-03-12, CLOSE LONG , 44.26
# 2021-03-12, SELL CREATE , 44.26
# 2021-03-15, SELL EXECUTED, 44.40
# 2021-03-15, SELL EXECUTED, 44.40
# 2021-03-15, CLOSE LONG , 45.67
# 2021-03-15, SELL CREATE , 45.67
# 2021-03-16, BUY EXECUTED, 46.67
# 2021-03-16, SELL EXECUTED, 46.67
# 2021-03-16, CLOSE LONG , 46.42
# 2021-03-16, SELL CREATE , 46.42
# 2021-03-17, BUY EXECUTED, 45.06
# 2021-03-17, SELL EXECUTED, 45.06
# 2021-03-17, CLOSE LONG , 47.01
# 2021-03-17, SELL CREATE , 47.01
# 2021-03-18, BUY EXECUTED, 44.81
# 2021-03-18, SELL EXECUTED, 44.81
# 2021-03-18, CLOSE LONG , 42.69
# 2021-03-18, SELL CREATE , 42.69
# 2021-03-19, BUY EXECUTED, 42.62
# 2021-03-19, SELL EXECUTED, 42.62
# 2021-03-19, CLOSE SHORT , 43.24
# 2021-03-19, BUY CREATE, 43.24
# 2021-03-22, BUY EXECUTED, 44.15
# 2021-03-22, BUY EXECUTED, 44.15
# 2021-03-22, CLOSE SHORT , 45.54
# 2021-03-22, BUY CREATE, 45.54
# 2021-03-23, SELL EXECUTED, 46.03
# 2021-03-23, BUY EXECUTED, 46.03
# 2021-03-23, CLOSE SHORT , 44.95
# 2021-03-23, BUY CREATE, 44.95
# 2021-03-24, SELL EXECUTED, 45.54
# 2021-03-24, BUY EXECUTED, 45.54
# 2021-03-24, CLOSE SHORT , 42.68
# 2021-03-24, BUY CREATE, 42.68
# 2021-03-25, SELL EXECUTED, 41.91
# 2021-03-25, BUY EXECUTED, 41.91
# 2021-03-25, CLOSE SHORT , 42.45
# 2021-03-25, BUY CREATE, 42.45
# 2021-03-26, SELL EXECUTED, 42.36
# 2021-03-26, BUY EXECUTED, 42.36
# 2021-03-26, CLOSE LONG , 44.33
# 2021-03-26, SELL CREATE , 44.33
# 2021-03-29, SELL EXECUTED, 44.12
# 2021-03-29, SELL EXECUTED, 44.12
# 2021-03-29, CLOSE SHORT , 44.30
# 2021-03-29, BUY CREATE, 44.30
# 2021-03-30, BUY EXECUTED, 43.47
# 2021-03-30, BUY EXECUTED, 43.47
# 2021-03-30, CLOSE SHORT , 43.67
# 2021-03-30, BUY CREATE, 43.67
# 2021-03-31, SELL EXECUTED, 44.40
# 2021-03-31, BUY EXECUTED, 44.40
# 2021-03-31, CLOSE SHORT , 45.63
# 2021-03-31, BUY CREATE, 45.63
# 2021-04-01, SELL EXECUTED, 47.32
# 2021-04-01, BUY EXECUTED, 47.32
# 2021-04-05, CLOSE LONG , 50.83
# 2021-04-05, SELL CREATE , 50.83
# 2021-04-06, SELL EXECUTED, 50.68
# 2021-04-06, SELL EXECUTED, 50.68
# 2021-04-09, CLOSE LONG , 53.63
# 2021-04-09, SELL CREATE , 53.63
# 2021-04-12, BUY EXECUTED, 53.15
# 2021-04-12, SELL EXECUTED, 53.15
# 2021-04-20, CLOSE SHORT , 53.19
# 2021-04-20, BUY CREATE, 53.19
# 2021-04-21, BUY EXECUTED, 52.50
# 2021-04-21, BUY EXECUTED, 52.50
# 2021-04-21, CLOSE LONG , 54.53
# 2021-04-21, SELL CREATE , 54.53
# 2021-04-22, SELL EXECUTED, 54.33
# 2021-04-22, SELL EXECUTED, 54.33
# 2021-04-22, CLOSE LONG , 52.55
# 2021-04-22, SELL CREATE , 52.55
# 2021-04-23, BUY EXECUTED, 52.86
# 2021-04-23, SELL EXECUTED, 52.86
# 2021-04-23, CLOSE LONG , 54.53
# 2021-04-23, SELL CREATE , 54.53
# 2021-04-26, BUY EXECUTED, 54.65
# 2021-04-26, SELL EXECUTED, 54.65
# 2021-04-27, CLOSE SHORT , 54.88
# 2021-04-27, BUY CREATE, 54.88
# 2021-04-28, BUY EXECUTED, 54.69
# 2021-04-28, BUY EXECUTED, 54.69
# 2021-04-29, CLOSE LONG , 54.86
# 2021-04-29, SELL CREATE , 54.86
# 2021-04-30, SELL EXECUTED, 53.65
# 2021-04-30, SELL EXECUTED, 53.65
# 2021-05-03, CLOSE LONG , 52.95
# 2021-05-03, SELL CREATE , 52.95
# 2021-05-04, BUY EXECUTED, 51.72
# 2021-05-04, SELL EXECUTED, 51.72
# 2021-05-04, CLOSE LONG , 50.16
# 2021-05-04, SELL CREATE , 50.16
# 2021-05-05, BUY EXECUTED, 51.02
# 2021-05-05, SELL EXECUTED, 51.02
# 2021-05-05, CLOSE SHORT , 49.58
# 2021-05-05, BUY CREATE, 49.58
# 2021-05-06, BUY EXECUTED, 49.44
# 2021-05-06, BUY EXECUTED, 49.44
# 2021-05-06, CLOSE SHORT , 50.66
# 2021-05-06, BUY CREATE, 50.66
# 2021-05-07, SELL EXECUTED, 51.99
# 2021-05-07, BUY EXECUTED, 51.99
# 2021-05-07, CLOSE SHORT , 51.90
# 2021-05-07, BUY CREATE, 51.90
# 2021-05-10, SELL EXECUTED, 51.24
# 2021-05-10, BUY EXECUTED, 51.24
# 2021-05-10, CLOSE SHORT , 48.00
# 2021-05-10, BUY CREATE, 48.00
# 2021-05-11, SELL EXECUTED, 45.29
# 2021-05-11, BUY EXECUTED, 45.29
# 2021-05-11, CLOSE SHORT , 47.76
# 2021-05-11, BUY CREATE, 47.76
# 2021-05-12, SELL EXECUTED, 45.51
# 2021-05-12, BUY EXECUTED, 45.51
# 2021-05-12, CLOSE LONG , 44.12
# 2021-05-12, SELL CREATE , 44.12
# 2021-05-13, SELL EXECUTED, 45.30
# 2021-05-13, SELL EXECUTED, 45.30
# 2021-05-13, CLOSE LONG , 45.06
# 2021-05-13, SELL CREATE , 45.06
# 2021-05-14, BUY EXECUTED, 46.44
# 2021-05-14, SELL EXECUTED, 46.44
# 2021-05-14, CLOSE LONG , 47.99
# 2021-05-14, SELL CREATE , 47.99
# 2021-05-17, BUY EXECUTED, 47.26
# 2021-05-17, SELL EXECUTED, 47.26
# 2021-05-17, CLOSE SHORT , 47.17
# 2021-05-17, BUY CREATE, 47.17
# 2021-05-18, BUY EXECUTED, 47.60
# 2021-05-18, BUY EXECUTED, 47.60
# 2021-05-18, CLOSE LONG , 46.19
# 2021-05-18, SELL CREATE , 46.19
# 2021-05-19, SELL EXECUTED, 43.83
# 2021-05-19, SELL EXECUTED, 43.83
# 2021-05-19, CLOSE LONG , 46.35
# 2021-05-19, SELL CREATE , 46.35
# 2021-05-20, BUY EXECUTED, 47.03
# 2021-05-20, SELL EXECUTED, 47.03
# 2021-05-20, CLOSE LONG , 49.03
# 2021-05-20, SELL CREATE , 49.03
# 2021-05-21, BUY EXECUTED, 49.77
# 2021-05-21, SELL EXECUTED, 49.77
# 2021-05-21, CLOSE SHORT , 48.22
# 2021-05-21, BUY CREATE, 48.22
# 2021-05-24, BUY EXECUTED, 49.28
# 2021-05-24, BUY EXECUTED, 49.28
# 2021-05-24, CLOSE LONG , 50.64
# 2021-05-24, SELL CREATE , 50.64
# 2021-05-25, SELL EXECUTED, 51.38
# 2021-05-25, SELL EXECUTED, 51.38
# 2021-05-25, CLOSE SHORT , 50.88
# 2021-05-25, BUY CREATE, 50.88
# 2021-05-26, BUY EXECUTED, 51.18
# 2021-05-26, BUY EXECUTED, 51.18
# 2021-05-26, CLOSE LONG , 51.40
# 2021-05-26, SELL CREATE , 51.40
# 2021-05-27, SELL EXECUTED, 51.19
# 2021-05-27, SELL EXECUTED, 51.19
# 2021-06-03, CLOSE LONG , 49.46
# 2021-06-03, SELL CREATE , 49.46
# 2021-06-04, BUY EXECUTED, 50.31
# 2021-06-04, SELL EXECUTED, 50.31
# 2021-06-04, CLOSE LONG , 51.99
# 2021-06-04, SELL CREATE , 51.99
# 2021-06-07, BUY EXECUTED, 51.72
# 2021-06-07, SELL EXECUTED, 51.72
# 2021-06-08, CLOSE SHORT , 52.51
# 2021-06-08, BUY CREATE, 52.51
# 2021-06-09, BUY EXECUTED, 53.18
# 2021-06-09, BUY EXECUTED, 53.18
# 2021-06-21, CLOSE LONG , 56.21
# 2021-06-21, SELL CREATE , 56.21
# 2021-06-22, SELL EXECUTED, 56.15
# 2021-06-22, SELL EXECUTED, 56.15
# 2021-06-29, CLOSE SHORT , 61.52
# 2021-06-29, BUY CREATE, 61.52
# 2021-06-30, BUY EXECUTED, 61.44
# 2021-06-30, BUY EXECUTED, 61.44
# 2021-07-08, CLOSE LONG , 63.50
# 2021-07-08, SELL CREATE , 63.50
# 2021-07-09, SELL EXECUTED, 63.14
# 2021-07-09, SELL EXECUTED, 63.14
# 2021-07-15, CLOSE SHORT , 64.35
# 2021-07-15, BUY CREATE, 64.35
# 2021-07-16, BUY EXECUTED, 64.83
# 2021-07-16, BUY EXECUTED, 64.83
# 2021-07-16, CLOSE SHORT , 62.76
# 2021-07-16, BUY CREATE, 62.76
# 2021-07-19, SELL EXECUTED, 60.90
# 2021-07-19, BUY EXECUTED, 60.90
# 2021-07-19, CLOSE SHORT , 61.26
# 2021-07-19, BUY CREATE, 61.26
# 2021-07-20, SELL EXECUTED, 61.72
# 2021-07-20, BUY EXECUTED, 61.72
# 2021-07-28, CLOSE SHORT , 67.05
# 2021-07-28, BUY CREATE, 67.05
# 2021-07-29, SELL EXECUTED, 66.74
# 2021-07-29, BUY EXECUTED, 66.74
# 2021-07-30, CLOSE SHORT , 66.37
# 2021-07-30, BUY CREATE, 66.37
# 2021-08-02, SELL EXECUTED, 67.27
# 2021-08-02, BUY EXECUTED, 67.27
# 2021-08-11, CLOSE SHORT , 67.19
# 2021-08-11, BUY CREATE, 67.19
# 2021-08-12, SELL EXECUTED, 66.90
# 2021-08-12, BUY EXECUTED, 66.90
# 2021-08-17, CLOSE SHORT , 66.89
# 2021-08-17, BUY CREATE, 66.89
# 2021-08-18, SELL EXECUTED, 66.55
# 2021-08-18, BUY EXECUTED, 66.55
# 2021-08-18, CLOSE SHORT , 64.94
# 2021-08-18, BUY CREATE, 64.94
# 2021-08-19, SELL EXECUTED, 63.87
# 2021-08-19, BUY EXECUTED, 63.87
# 2021-08-20, CLOSE SHORT , 67.90
# 2021-08-20, BUY CREATE, 67.90
# 2021-08-23, SELL EXECUTED, 68.51
# 2021-08-23, BUY EXECUTED, 68.51
# 2021-08-23, CLOSE LONG , 70.93
# 2021-08-23, SELL CREATE , 70.93
# 2021-08-24, SELL EXECUTED, 71.31
# 2021-08-24, SELL EXECUTED, 71.31
# 2021-09-10, CLOSE LONG , 72.78
# 2021-09-10, SELL CREATE , 72.78
# 2021-09-13, BUY EXECUTED, 74.14
# 2021-09-13, SELL EXECUTED, 74.14
# 2021-09-13, CLOSE LONG , 72.61
# 2021-09-13, SELL CREATE , 72.61
# 2021-09-14, BUY EXECUTED, 73.47
# 2021-09-14, SELL EXECUTED, 73.47
# 2021-09-14, CLOSE LONG , 71.99
# 2021-09-14, SELL CREATE , 71.99
# 2021-09-15, BUY EXECUTED, 72.25
# 2021-09-15, SELL EXECUTED, 72.25
# 2021-09-15, CLOSE LONG , 73.58
# 2021-09-15, SELL CREATE , 73.58
# 2021-09-16, BUY EXECUTED, 72.78
# 2021-09-16, SELL EXECUTED, 72.78
# 2021-09-16, CLOSE SHORT , 73.72
# 2021-09-16, BUY CREATE, 73.72
# 2021-09-17, BUY EXECUTED, 73.45
# 2021-09-17, BUY EXECUTED, 73.45
# 2021-09-17, CLOSE LONG , 71.12
# 2021-09-17, SELL CREATE , 71.12
# 2021-09-20, SELL EXECUTED, 67.71
# 2021-09-20, SELL EXECUTED, 67.71
# 2021-09-20, CLOSE LONG , 66.75
# 2021-09-20, SELL CREATE , 66.75
# 2021-09-21, BUY EXECUTED, 67.69
# 2021-09-21, SELL EXECUTED, 67.69
# 2021-09-21, CLOSE SHORT , 66.83
# 2021-09-21, BUY CREATE, 66.83
# 2021-09-22, BUY EXECUTED, 67.43
# 2021-09-22, BUY EXECUTED, 67.43
# 2021-09-22, CLOSE LONG , 68.79
# 2021-09-22, SELL CREATE , 68.79
# 2021-09-23, SELL EXECUTED, 69.46
# 2021-09-23, SELL EXECUTED, 69.46
# 2021-09-23, CLOSE SHORT , 70.69
# 2021-09-23, BUY CREATE, 70.69
# 2021-09-24, BUY EXECUTED, 69.36
# 2021-09-24, BUY EXECUTED, 69.36
# 2021-09-24, CLOSE SHORT , 70.89
# 2021-09-24, BUY CREATE, 70.89
# 2021-09-27, SELL EXECUTED, 69.11
# 2021-09-27, BUY EXECUTED, 69.11
# 2021-09-29, CLOSE SHORT , 62.99
# 2021-09-29, BUY CREATE, 62.99
# 2021-09-30, SELL EXECUTED, 63.89
# 2021-09-30, BUY EXECUTED, 63.89
# 2021-10-01, CLOSE LONG , 63.42
# 2021-10-01, SELL CREATE , 63.42
# 2021-10-04, SELL EXECUTED, 62.55
# 2021-10-04, SELL EXECUTED, 62.55
# 2021-10-04, CLOSE LONG , 59.52
# 2021-10-04, SELL CREATE , 59.52
# 2021-10-05, BUY EXECUTED, 59.99
# 2021-10-05, SELL EXECUTED, 59.99
# 2021-10-05, CLOSE LONG , 61.81
# 2021-10-05, SELL CREATE , 61.81
# 2021-10-06, BUY EXECUTED, 60.13
# 2021-10-06, SELL EXECUTED, 60.13
# 2021-10-06, CLOSE LONG , 63.03
# 2021-10-06, SELL CREATE , 63.03
# 2021-10-07, BUY EXECUTED, 64.66
# 2021-10-07, SELL EXECUTED, 64.66
# 2021-10-07, CLOSE SHORT , 64.74
# 2021-10-07, BUY CREATE, 64.74
# 2021-10-08, BUY EXECUTED, 65.33
# 2021-10-08, BUY EXECUTED, 65.33
# 2021-10-08, CLOSE SHORT , 63.74
# 2021-10-08, BUY CREATE, 63.74
# 2021-10-11, SELL EXECUTED, 62.93
# 2021-10-11, BUY EXECUTED, 62.93
# 2021-10-11, CLOSE LONG , 62.33
# 2021-10-11, SELL CREATE , 62.33
# 2021-10-12, SELL EXECUTED, 63.08
# 2021-10-12, SELL EXECUTED, 63.08
# 2021-10-12, CLOSE SHORT , 61.69
# 2021-10-12, BUY CREATE, 61.69
# 2021-10-13, BUY EXECUTED, 62.89
# 2021-10-13, BUY EXECUTED, 62.89
# 2021-10-13, CLOSE LONG , 63.13
# 2021-10-13, SELL CREATE , 63.13
# 2021-10-14, SELL EXECUTED, 65.06
# 2021-10-14, SELL EXECUTED, 65.06
# 2021-10-14, CLOSE SHORT , 66.62
# 2021-10-14, BUY CREATE, 66.62
# 2021-10-15, BUY EXECUTED, 67.30
# 2021-10-15, BUY EXECUTED, 67.30
# 2021-10-18, CLOSE LONG , 69.89
# 2021-10-18, SELL CREATE , 69.89
# 2021-10-19, SELL EXECUTED, 70.52
# 2021-10-19, SELL EXECUTED, 70.52
# 2021-10-25, CLOSE LONG , 72.76
# 2021-10-25, SELL CREATE , 72.76
# 2021-10-26, BUY EXECUTED, 74.16
# 2021-10-26, SELL EXECUTED, 74.16
# 2021-10-26, CLOSE SHORT , 73.44
# 2021-10-26, BUY CREATE, 73.44
# 2021-10-27, BUY EXECUTED, 73.78
# 2021-10-27, BUY EXECUTED, 73.78
# 2021-11-09, CLOSE LONG , 83.18
# 2021-11-09, SELL CREATE , 83.18
# 2021-11-10, SELL EXECUTED, 81.36
# 2021-11-10, SELL EXECUTED, 81.36
# 2021-11-10, CLOSE LONG , 79.54
# 2021-11-10, SELL CREATE , 79.54
# 2021-11-11, BUY EXECUTED, 81.38
# 2021-11-11, SELL EXECUTED, 81.38
# 2021-11-11, CLOSE SHORT , 80.18
# 2021-11-11, BUY CREATE, 80.18
# 2021-11-12, BUY EXECUTED, 80.90
# 2021-11-12, BUY EXECUTED, 80.90
# 2021-11-12, CLOSE SHORT , 82.72
# 2021-11-12, BUY CREATE, 82.72
# 2021-11-15, SELL EXECUTED, 83.46
# 2021-11-15, BUY EXECUTED, 83.46
# 2021-11-24, CLOSE LONG , 85.11
# 2021-11-24, SELL CREATE , 85.11
# 2021-11-26, SELL EXECUTED, 83.39
# 2021-11-26, SELL EXECUTED, 83.39
# 2021-11-26, CLOSE LONG , 80.42
# 2021-11-26, SELL CREATE , 80.42
# 2021-11-29, BUY EXECUTED, 83.10
# 2021-11-29, SELL EXECUTED, 83.10
# 2021-11-29, CLOSE LONG , 85.42
# 2021-11-29, SELL CREATE , 85.42
# 2021-11-30, BUY EXECUTED, 84.84
# 2021-11-30, SELL EXECUTED, 84.84
# 2021-11-30, CLOSE LONG , 81.75
# 2021-11-30, SELL CREATE , 81.75
# 2021-12-01, BUY EXECUTED, 84.43
# 2021-12-01, SELL EXECUTED, 84.43
# 2021-12-01, CLOSE SHORT , 77.55
# 2021-12-01, BUY CREATE, 77.55
# 2021-12-02, BUY EXECUTED, 76.71
# 2021-12-02, BUY EXECUTED, 76.71
# 2021-12-02, CLOSE LONG , 79.01
# 2021-12-02, SELL CREATE , 79.01
# 2021-12-03, SELL EXECUTED, 80.00
# 2021-12-03, SELL EXECUTED, 80.00
# 2021-12-03, CLOSE SHORT , 75.04
# 2021-12-03, BUY CREATE, 75.04
# 2021-12-06, BUY EXECUTED, 75.29
# 2021-12-06, BUY EXECUTED, 75.29
# 2021-12-06, CLOSE LONG , 76.79
# 2021-12-06, SELL CREATE , 76.79
# 2021-12-07, SELL EXECUTED, 80.89
# 2021-12-07, SELL EXECUTED, 80.89
# 2021-12-07, CLOSE SHORT , 83.72
# 2021-12-07, BUY CREATE, 83.72
# 2021-12-08, BUY EXECUTED, 83.94
# 2021-12-08, BUY EXECUTED, 83.94
# 2021-12-08, CLOSE SHORT , 84.89
# 2021-12-08, BUY CREATE, 84.89
# 2021-12-09, SELL EXECUTED, 84.07
# 2021-12-09, BUY EXECUTED, 84.07
# 2021-12-09, CLOSE LONG , 81.22
# 2021-12-09, SELL CREATE , 81.22
# 2021-12-10, SELL EXECUTED, 82.89
# 2021-12-10, SELL EXECUTED, 82.89
# 2021-12-13, CLOSE SHORT , 80.14
# 2021-12-13, BUY CREATE, 80.14
# 2021-12-14, BUY EXECUTED, 77.06
# 2021-12-14, BUY EXECUTED, 77.06
# 2021-12-14, CLOSE LONG , 77.75
# 2021-12-14, SELL CREATE , 77.75
# 2021-12-15, SELL EXECUTED, 77.48
# 2021-12-15, SELL EXECUTED, 77.48
# 2021-12-15, CLOSE LONG , 82.89
# 2021-12-15, SELL CREATE , 82.89
# 2021-12-16, BUY EXECUTED, 83.50
# 2021-12-16, SELL EXECUTED, 83.50
# 2021-12-16, CLOSE SHORT , 76.57
# 2021-12-16, BUY CREATE, 76.57
# 2021-12-17, BUY EXECUTED, 74.42
# 2021-12-17, BUY EXECUTED, 74.42
# 2021-12-17, CLOSE LONG , 75.40
# 2021-12-17, SELL CREATE , 75.40
# 2021-12-20, SELL EXECUTED, 72.51
# 2021-12-20, SELL EXECUTED, 72.51
# 2021-12-20, CLOSE SHORT , 73.14
# 2021-12-20, BUY CREATE, 73.14
# 2021-12-21, BUY EXECUTED, 75.08
# 2021-12-21, BUY EXECUTED, 75.08
# 2021-12-21, CLOSE SHORT , 78.04
# 2021-12-21, BUY CREATE, 78.04
# 2021-12-22, SELL EXECUTED, 77.79
# 2021-12-22, BUY EXECUTED, 77.79
# 2021-12-22, CLOSE SHORT , 80.82
# 2021-12-22, BUY CREATE, 80.82
# 2021-12-23, SELL EXECUTED, 81.08
# 2021-12-23, BUY EXECUTED, 81.08
# 2021-12-27, CLOSE LONG , 86.69
# 2021-12-27, SELL CREATE , 86.69
# 2021-12-28, SELL EXECUTED, 87.38
# 2021-12-28, SELL EXECUTED, 87.38
# 2021-12-31, CLOSE SHORT , 83.17
# 2021-12-31, BUY CREATE, 83.17
# 2022-01-03, BUY EXECUTED, 83.92
# 2022-01-03, BUY EXECUTED, 83.92
# 2022-01-03, CLOSE LONG , 85.57
# 2022-01-03, SELL CREATE , 85.57
# 2022-01-04, SELL EXECUTED, 85.92
# 2022-01-04, SELL EXECUTED, 85.92
# 2022-01-05, CLOSE LONG , 74.68
# 2022-01-05, SELL CREATE , 74.68
# 2022-01-06, BUY EXECUTED, 73.51
# 2022-01-06, SELL EXECUTED, 73.51
# 2022-01-06, CLOSE SHORT , 74.47
# 2022-01-06, BUY CREATE, 74.47
# 2022-01-07, BUY EXECUTED, 74.45
# 2022-01-07, BUY EXECUTED, 74.45
# 2022-01-10, CLOSE SHORT , 72.30
# 2022-01-10, BUY CREATE, 72.30
# 2022-01-11, SELL EXECUTED, 71.71
# 2022-01-11, BUY EXECUTED, 71.71
# 2022-01-11, CLOSE LONG , 75.48
# 2022-01-11, SELL CREATE , 75.48
# 2022-01-12, SELL EXECUTED, 76.99
# 2022-01-12, SELL EXECUTED, 76.99
# 2022-01-12, CLOSE LONG , 76.34
# 2022-01-12, SELL CREATE , 76.34
# 2022-01-13, BUY EXECUTED, 77.13
# 2022-01-13, SELL EXECUTED, 77.13
# 2022-01-13, CLOSE SHORT , 70.80
# 2022-01-13, BUY CREATE, 70.80
# 2022-01-14, BUY EXECUTED, 69.09
# 2022-01-14, BUY EXECUTED, 69.09
# 2022-01-14, CLOSE SHORT , 71.87
# 2022-01-14, BUY CREATE, 71.87
# 2022-01-18, SELL EXECUTED, 68.49
# 2022-01-18, BUY EXECUTED, 68.49
# 2022-01-18, CLOSE LONG , 66.69
# 2022-01-18, SELL CREATE , 66.69
# 2022-01-19, SELL EXECUTED, 67.36
# 2022-01-19, SELL EXECUTED, 67.36
# 2022-01-19, CLOSE LONG , 64.37
# 2022-01-19, SELL CREATE , 64.37
# 2022-01-20, BUY EXECUTED, 66.02
# 2022-01-20, SELL EXECUTED, 66.02
# 2022-01-20, CLOSE LONG , 61.88
# 2022-01-20, SELL CREATE , 61.88
# 2022-01-21, BUY EXECUTED, 60.62
# 2022-01-21, SELL EXECUTED, 60.62
# 2022-01-21, CLOSE LONG , 56.67
# 2022-01-21, SELL CREATE , 56.67
# 2022-01-24, BUY EXECUTED, 53.85
# 2022-01-24, SELL EXECUTED, 53.85
# 2022-01-24, CLOSE SHORT , 57.49
# 2022-01-24, BUY CREATE, 57.49
# 2022-01-25, BUY EXECUTED, 54.15
# 2022-01-25, BUY EXECUTED, 54.15
# 2022-01-25, CLOSE SHORT , 53.25
# 2022-01-25, BUY CREATE, 53.25
# 2022-01-26, SELL EXECUTED, 56.99
# 2022-01-26, BUY EXECUTED, 56.99
# 2022-01-26, CLOSE SHORT , 53.15
# 2022-01-26, BUY CREATE, 53.15
# 2022-01-27, SELL EXECUTED, 55.40
# 2022-01-27, BUY EXECUTED, 55.40
# 2022-01-27, CLOSE SHORT , 51.56
# 2022-01-27, BUY CREATE, 51.56
# 2022-01-28, SELL EXECUTED, 52.40
# 2022-01-28, BUY EXECUTED, 52.40
# 2022-01-28, CLOSE SHORT , 56.37
# 2022-01-28, BUY CREATE, 56.37
# 2022-01-31, SELL EXECUTED, 57.05
# 2022-01-31, BUY EXECUTED, 57.05
# 2022-01-31, CLOSE SHORT , 61.83
# 2022-01-31, BUY CREATE, 61.83
# 2022-02-01, SELL EXECUTED, 62.42
# 2022-02-01, BUY EXECUTED, 62.42
# 2022-02-01, CLOSE SHORT , 63.01
# 2022-02-01, BUY CREATE, 63.01
# 2022-02-02, SELL EXECUTED, 65.22
# 2022-02-02, BUY EXECUTED, 65.22
# 2022-02-02, CLOSE SHORT , 64.50
# 2022-02-02, BUY CREATE, 64.50
# 2022-02-03, SELL EXECUTED, 59.32
# 2022-02-03, BUY EXECUTED, 59.32
# 2022-02-03, CLOSE LONG , 56.74
# 2022-02-03, SELL CREATE , 56.74
# 2022-02-04, SELL EXECUTED, 56.87
# 2022-02-04, SELL EXECUTED, 56.87
# 2022-02-04, CLOSE LONG , 58.70
# 2022-02-04, SELL CREATE , 58.70
# 2022-02-07, BUY EXECUTED, 59.07
# 2022-02-07, SELL EXECUTED, 59.07
# 2022-02-07, CLOSE SHORT , 57.37
# 2022-02-07, BUY CREATE, 57.37
# 2022-02-08, BUY EXECUTED, 56.80
# 2022-02-08, BUY EXECUTED, 56.80
# 2022-02-08, CLOSE SHORT , 59.32
# 2022-02-08, BUY CREATE, 59.32
# 2022-02-09, SELL EXECUTED, 61.56
# 2022-02-09, BUY EXECUTED, 61.56
# 2022-02-09, CLOSE SHORT , 63.00
# 2022-02-09, BUY CREATE, 63.00
# 2022-02-10, SELL EXECUTED, 59.31
# 2022-02-10, BUY EXECUTED, 59.31
# 2022-02-10, CLOSE LONG , 58.82
# 2022-02-10, SELL CREATE , 58.82
# 2022-02-11, SELL EXECUTED, 58.78
# 2022-02-11, SELL EXECUTED, 58.78
# 2022-02-11, CLOSE LONG , 53.28
# 2022-02-11, SELL CREATE , 53.28
# 2022-02-14, BUY EXECUTED, 52.90
# 2022-02-14, SELL EXECUTED, 52.90
# 2022-02-14, CLOSE SHORT , 53.43
# 2022-02-14, BUY CREATE, 53.43
# 2022-02-15, BUY EXECUTED, 55.83
# 2022-02-15, BUY EXECUTED, 55.83
# 2022-02-15, CLOSE SHORT , 57.30
# 2022-02-15, BUY CREATE, 57.30
# 2022-02-16, SELL EXECUTED, 56.27
# 2022-02-16, BUY EXECUTED, 56.27
# 2022-02-16, CLOSE LONG , 57.29
# 2022-02-16, SELL CREATE , 57.29
# 2022-02-17, SELL EXECUTED, 55.64
# 2022-02-17, SELL EXECUTED, 55.64
# 2022-02-17, CLOSE LONG , 52.21
# 2022-02-17, SELL CREATE , 52.21
# 2022-02-18, BUY EXECUTED, 52.59
# 2022-02-18, SELL EXECUTED, 52.59
# 2022-02-18, CLOSE LONG , 50.44
# 2022-02-18, SELL CREATE , 50.44
# 2022-02-22, BUY EXECUTED, 49.04
# 2022-02-22, SELL EXECUTED, 49.04
# 2022-02-22, CLOSE LONG , 48.88
# 2022-02-22, SELL CREATE , 48.88
# 2022-02-23, BUY EXECUTED, 50.24
# 2022-02-23, SELL EXECUTED, 50.24
# 2022-02-23, CLOSE SHORT , 45.14
# 2022-02-23, BUY CREATE, 45.14
# 2022-02-24, BUY EXECUTED, 40.76
# 2022-02-24, BUY EXECUTED, 40.76
# 2022-02-24, CLOSE LONG , 49.56
# 2022-02-24, SELL CREATE , 49.56
# 2022-02-25, SELL EXECUTED, 50.00
# 2022-02-25, SELL EXECUTED, 50.00
# 2022-02-25, CLOSE SHORT , 51.91
# 2022-02-25, BUY CREATE, 51.91
# 2022-02-28, BUY EXECUTED, 50.46
# 2022-02-28, BUY EXECUTED, 50.46
# 2022-02-28, CLOSE SHORT , 52.46
# 2022-02-28, BUY CREATE, 52.46
# 2022-03-01, SELL EXECUTED, 51.92
# 2022-03-01, BUY EXECUTED, 51.92
# 2022-03-01, CLOSE SHORT , 50.04
# 2022-03-01, BUY CREATE, 50.04
# 2022-03-02, SELL EXECUTED, 50.67
# 2022-03-02, BUY EXECUTED, 50.67
# 2022-03-02, CLOSE SHORT , 52.43
# 2022-03-02, BUY CREATE, 52.43
# 2022-03-03, SELL EXECUTED, 53.75
# 2022-03-03, BUY EXECUTED, 53.75
# 2022-03-03, CLOSE LONG , 50.24
# 2022-03-03, SELL CREATE , 50.24
# 2022-03-04, SELL EXECUTED, 49.17
# 2022-03-04, SELL EXECUTED, 49.17
# 2022-03-04, CLOSE LONG , 48.09
# 2022-03-04, SELL CREATE , 48.09
# 2022-03-07, BUY EXECUTED, 48.05
# 2022-03-07, SELL EXECUTED, 48.05
# 2022-03-07, CLOSE SHORT , 42.72
# 2022-03-07, BUY CREATE, 42.72
# 2022-03-08, BUY EXECUTED, 42.39
# 2022-03-08, BUY EXECUTED, 42.39
# 2022-03-08, CLOSE SHORT , 42.13
# 2022-03-08, BUY CREATE, 42.13
# 2022-03-09, SELL EXECUTED, 45.40
# 2022-03-09, BUY EXECUTED, 45.40
# 2022-03-09, CLOSE LONG , 46.64
# 2022-03-09, SELL CREATE , 46.64
# 2022-03-10, SELL EXECUTED, 44.90
# 2022-03-10, SELL EXECUTED, 44.90
# 2022-03-10, CLOSE LONG , 45.14
# 2022-03-10, SELL CREATE , 45.14
# 2022-03-11, BUY EXECUTED, 46.34
# 2022-03-11, SELL EXECUTED, 46.34
# 2022-03-11, CLOSE SHORT , 42.34
# 2022-03-11, BUY CREATE, 42.34
# 2022-03-14, BUY EXECUTED, 41.81
# 2022-03-14, BUY EXECUTED, 41.81
# 2022-03-14, CLOSE LONG , 39.86
# 2022-03-14, SELL CREATE , 39.86
# 2022-03-15, SELL EXECUTED, 40.87
# 2022-03-15, SELL EXECUTED, 40.87
# 2022-03-15, CLOSE LONG , 43.55
# 2022-03-15, SELL CREATE , 43.55
# 2022-03-16, BUY EXECUTED, 45.16
# 2022-03-16, SELL EXECUTED, 45.16
# 2022-03-16, CLOSE SHORT , 48.44
# 2022-03-16, BUY CREATE, 48.44
# 2022-03-17, BUY EXECUTED, 47.59
# 2022-03-17, BUY EXECUTED, 47.59
# 2022-03-17, CLOSE SHORT , 50.06
# 2022-03-17, BUY CREATE, 50.06
# 2022-03-18, SELL EXECUTED, 49.46
# 2022-03-18, BUY EXECUTED, 49.46
# 2022-03-18, CLOSE SHORT , 53.17
# 2022-03-18, BUY CREATE, 53.17
# 2022-03-21, SELL EXECUTED, 52.86
# 2022-03-21, BUY EXECUTED, 52.86
# 2022-03-21, CLOSE SHORT , 52.79
# 2022-03-21, BUY CREATE, 52.79
# 2022-03-22, SELL EXECUTED, 53.07
# 2022-03-22, BUY EXECUTED, 53.07
# 2022-03-22, CLOSE LONG , 55.91
# 2022-03-22, SELL CREATE , 55.91
# 2022-03-23, SELL EXECUTED, 54.56
# 2022-03-23, SELL EXECUTED, 54.56
# 2022-03-24, CLOSE LONG , 57.02
# 2022-03-24, SELL CREATE , 57.02
# 2022-03-25, BUY EXECUTED, 57.04
# 2022-03-25, SELL EXECUTED, 57.04
# 2022-03-25, CLOSE LONG , 56.93
# 2022-03-25, SELL CREATE , 56.93
# 2022-03-28, BUY EXECUTED, 56.92
# 2022-03-28, SELL EXECUTED, 56.92
# 2022-03-28, CLOSE LONG , 59.52
# 2022-03-28, SELL CREATE , 59.52
# 2022-03-29, BUY EXECUTED, 61.52
# 2022-03-29, SELL EXECUTED, 61.52
# 2022-03-30, CLOSE LONG , 60.69
# 2022-03-30, SELL CREATE , 60.69
# 2022-03-31, BUY EXECUTED, 60.64
# 2022-03-31, SELL EXECUTED, 60.64
# 2022-03-31, CLOSE SHORT , 58.18
# 2022-03-31, BUY CREATE, 58.18
# 2022-04-01, BUY EXECUTED, 58.43
# 2022-04-01, BUY EXECUTED, 58.43
# 2022-04-01, CLOSE LONG , 57.93
# 2022-04-01, SELL CREATE , 57.93
# 2022-04-04, SELL EXECUTED, 58.38
# 2022-04-04, SELL EXECUTED, 58.38
# 2022-04-04, CLOSE LONG , 61.55
# 2022-04-04, SELL CREATE , 61.55
# 2022-04-05, BUY EXECUTED, 60.82
# 2022-04-05, SELL EXECUTED, 60.82
# 2022-04-05, CLOSE SHORT , 57.48
# 2022-04-05, BUY CREATE, 57.48
# 2022-04-06, BUY EXECUTED, 54.82
# 2022-04-06, BUY EXECUTED, 54.82
# 2022-04-06, CLOSE LONG , 53.70
# 2022-04-06, SELL CREATE , 53.70
# 2022-04-07, SELL EXECUTED, 53.23
# 2022-04-07, SELL EXECUTED, 53.23
# 2022-04-07, CLOSE LONG , 54.05
# 2022-04-07, SELL CREATE , 54.05
# 2022-04-08, BUY EXECUTED, 53.22
# 2022-04-08, SELL EXECUTED, 53.22
# 2022-04-08, CLOSE LONG , 51.84
# 2022-04-08, SELL CREATE , 51.84
# 2022-04-11, BUY EXECUTED, 49.83
# 2022-04-11, SELL EXECUTED, 49.83
# 2022-04-11, CLOSE LONG , 48.16
# 2022-04-11, SELL CREATE , 48.16
# 2022-04-12, BUY EXECUTED, 50.16
# 2022-04-12, SELL EXECUTED, 50.16
# 2022-04-12, CLOSE LONG , 47.54
# 2022-04-12, SELL CREATE , 47.54
# 2022-04-13, BUY EXECUTED, 47.66
# 2022-04-13, SELL EXECUTED, 47.66
# 2022-04-13, CLOSE LONG , 50.39
# 2022-04-13, SELL CREATE , 50.39
# 2022-04-14, BUY EXECUTED, 50.42
# 2022-04-14, SELL EXECUTED, 50.42
# 2022-04-14, CLOSE LONG , 47.00
# 2022-04-14, SELL CREATE , 47.00
# 2022-04-18, BUY EXECUTED, 46.47
# 2022-04-18, SELL EXECUTED, 46.47
# 2022-04-19, CLOSE LONG , 50.16
# 2022-04-19, SELL CREATE , 50.16
# 2022-04-20, BUY EXECUTED, 50.57
# 2022-04-20, SELL EXECUTED, 50.57
# 2022-04-20, CLOSE LONG , 47.90
# 2022-04-20, SELL CREATE , 47.90
# 2022-04-21, BUY EXECUTED, 49.64
# 2022-04-21, SELL EXECUTED, 49.64
# 2022-04-21, CLOSE LONG , 45.09
# 2022-04-21, SELL CREATE , 45.09
# 2022-04-22, BUY EXECUTED, 45.05
# 2022-04-22, SELL EXECUTED, 45.05
# 2022-04-22, CLOSE LONG , 41.51
# 2022-04-22, SELL CREATE , 41.51
# 2022-04-25, BUY EXECUTED, 40.81
# 2022-04-25, SELL EXECUTED, 40.81
# 2022-04-25, CLOSE SHORT , 43.05
# 2022-04-25, BUY CREATE, 43.05
# 2022-04-26, BUY EXECUTED, 42.22
# 2022-04-26, BUY EXECUTED, 42.22
# 2022-04-26, CLOSE SHORT , 38.21
# 2022-04-26, BUY CREATE, 38.21
# 2022-04-27, SELL EXECUTED, 38.17
# 2022-04-27, BUY EXECUTED, 38.17
# 2022-04-27, CLOSE SHORT , 38.04
# 2022-04-27, BUY CREATE, 38.04
# 2022-04-28, SELL EXECUTED, 39.83
# 2022-04-28, BUY EXECUTED, 39.83
# 2022-04-28, CLOSE LONG , 42.06
# 2022-04-28, SELL CREATE , 42.06
# 2022-04-29, SELL EXECUTED, 40.39
# 2022-04-29, SELL EXECUTED, 40.39
# 2022-04-29, CLOSE LONG , 36.53
# 2022-04-29, SELL CREATE , 36.53
# 2022-05-02, BUY EXECUTED, 36.25
# 2022-05-02, SELL EXECUTED, 36.25
# 2022-05-02, CLOSE LONG , 38.25
# 2022-05-02, SELL CREATE , 38.25
# 2022-05-03, BUY EXECUTED, 38.19
# 2022-05-03, SELL EXECUTED, 38.19
# 2022-05-03, CLOSE SHORT , 38.34
# 2022-05-03, BUY CREATE, 38.34
# 2022-05-04, BUY EXECUTED, 38.49
# 2022-05-04, BUY EXECUTED, 38.49
# 2022-05-04, CLOSE SHORT , 42.14
# 2022-05-04, BUY CREATE, 42.14
# 2022-05-05, SELL EXECUTED, 40.50
# 2022-05-05, BUY EXECUTED, 40.50
# 2022-05-05, CLOSE LONG , 35.86
# 2022-05-05, SELL CREATE , 35.86
# 2022-05-06, SELL EXECUTED, 35.09
# 2022-05-06, SELL EXECUTED, 35.09
# 2022-05-06, CLOSE SHORT , 34.61
# 2022-05-06, BUY CREATE, 34.61
# 2022-05-09, BUY EXECUTED, 32.56
# 2022-05-09, BUY EXECUTED, 32.56
# 2022-05-09, CLOSE SHORT , 30.52
# 2022-05-09, BUY CREATE, 30.52
# 2022-05-10, SELL EXECUTED, 32.72
# 2022-05-10, BUY EXECUTED, 32.72
# 2022-05-10, CLOSE SHORT , 31.57
# 2022-05-10, BUY CREATE, 31.57
# 2022-05-11, SELL EXECUTED, 30.85
# 2022-05-11, BUY EXECUTED, 30.85
# 2022-05-11, CLOSE SHORT , 28.76
# 2022-05-11, BUY CREATE, 28.76
# 2022-05-12, SELL EXECUTED, 27.43
# 2022-05-12, BUY EXECUTED, 27.43
# 2022-05-12, CLOSE LONG , 28.53
# 2022-05-12, SELL CREATE , 28.53
# 2022-05-13, SELL EXECUTED, 29.85
# 2022-05-13, SELL EXECUTED, 29.85
# 2022-05-13, CLOSE LONG , 31.63
# 2022-05-13, SELL CREATE , 31.63
# 2022-05-16, BUY EXECUTED, 31.13
# 2022-05-16, SELL EXECUTED, 31.13
# 2022-05-16, CLOSE SHORT , 30.65
# 2022-05-16, BUY CREATE, 30.65
# 2022-05-17, BUY EXECUTED, 32.43
# 2022-05-17, BUY EXECUTED, 32.43
# 2022-05-17, CLOSE SHORT , 32.96
# 2022-05-17, BUY CREATE, 32.96
# 2022-05-18, SELL EXECUTED, 31.46
# 2022-05-18, BUY EXECUTED, 31.46
# 2022-05-18, CLOSE SHORT , 28.15
# 2022-05-18, BUY CREATE, 28.15
# 2022-05-19, SELL EXECUTED, 27.54
# 2022-05-19, BUY EXECUTED, 27.54
# 2022-05-19, CLOSE SHORT , 27.58
# 2022-05-19, BUY CREATE, 27.58
# 2022-05-20, SELL EXECUTED, 28.65
# 2022-05-20, BUY EXECUTED, 28.65
# 2022-05-20, CLOSE LONG , 27.34
# 2022-05-20, SELL CREATE , 27.34
# 2022-05-23, SELL EXECUTED, 27.65
# 2022-05-23, SELL EXECUTED, 27.65
# 2022-05-23, CLOSE SHORT , 28.69
# 2022-05-23, BUY CREATE, 28.69
# 2022-05-24, BUY EXECUTED, 27.15
# 2022-05-24, BUY EXECUTED, 27.15
# 2022-05-24, CLOSE LONG , 26.90
# 2022-05-24, SELL CREATE , 26.90
# 2022-05-25, SELL EXECUTED, 26.44
# 2022-05-25, SELL EXECUTED, 26.44
# 2022-05-25, CLOSE SHORT , 27.98
# 2022-05-25, BUY CREATE, 27.98
# 2022-05-26, BUY EXECUTED, 27.76
# 2022-05-26, BUY EXECUTED, 27.76
# 2022-05-26, CLOSE LONG , 30.32
# 2022-05-26, SELL CREATE , 30.32
# 2022-05-27, SELL EXECUTED, 31.30
# 2022-05-27, SELL EXECUTED, 31.30
# 2022-05-27, CLOSE LONG , 33.29
# 2022-05-27, SELL CREATE , 33.29
# 2022-05-31, BUY EXECUTED, 33.30
# 2022-05-31, SELL EXECUTED, 33.30
# 2022-05-31, CLOSE SHORT , 33.05
# 2022-05-31, BUY CREATE, 33.05
# 2022-06-01, BUY EXECUTED, 33.71
# 2022-06-01, BUY EXECUTED, 33.71
# 2022-06-01, CLOSE SHORT , 32.28
# 2022-06-01, BUY CREATE, 32.28
# 2022-06-02, SELL EXECUTED, 31.92
# 2022-06-02, BUY EXECUTED, 31.92
# 2022-06-02, CLOSE LONG , 34.90
# 2022-06-02, SELL CREATE , 34.90
# 2022-06-03, SELL EXECUTED, 33.14
# 2022-06-03, SELL EXECUTED, 33.14
# 2022-06-03, CLOSE SHORT , 32.14
# 2022-06-03, BUY CREATE, 32.14
# 2022-06-06, BUY EXECUTED, 33.62
# 2022-06-06, BUY EXECUTED, 33.62
# 2022-06-06, CLOSE LONG , 32.54
# 2022-06-06, SELL CREATE , 32.54
# 2022-06-07, SELL EXECUTED, 31.42
# 2022-06-07, SELL EXECUTED, 31.42
# 2022-06-07, CLOSE LONG , 33.33
# 2022-06-07, SELL CREATE , 33.33
# 2022-06-08, BUY EXECUTED, 33.08
# 2022-06-08, SELL EXECUTED, 33.08
# 2022-06-08, CLOSE SHORT , 32.65
# 2022-06-08, BUY CREATE, 32.65
# 2022-06-09, BUY EXECUTED, 32.07
# 2022-06-09, BUY EXECUTED, 32.07
# 2022-06-09, CLOSE LONG , 29.99
# 2022-06-09, SELL CREATE , 29.99
# 2022-06-10, SELL EXECUTED, 28.26
# 2022-06-10, SELL EXECUTED, 28.26
# 2022-06-10, CLOSE LONG , 26.79
# 2022-06-10, SELL CREATE , 26.79
# 2022-06-13, BUY EXECUTED, 24.27
# 2022-06-13, SELL EXECUTED, 24.27
# 2022-06-13, CLOSE LONG , 23.08
# 2022-06-13, SELL CREATE , 23.08
# 2022-06-14, BUY EXECUTED, 23.64
# 2022-06-14, SELL EXECUTED, 23.64
# 2022-06-14, CLOSE LONG , 23.23
# 2022-06-14, SELL CREATE , 23.23
# 2022-06-15, BUY EXECUTED, 24.06
# 2022-06-15, SELL EXECUTED, 24.06
# 2022-06-15, CLOSE LONG , 24.90
# 2022-06-15, SELL CREATE , 24.90
# 2022-06-16, BUY EXECUTED, 22.99
# 2022-06-16, SELL EXECUTED, 22.99
# 2022-06-16, CLOSE SHORT , 21.86
# 2022-06-16, BUY CREATE, 21.86
# 2022-06-17, BUY EXECUTED, 22.07
# 2022-06-17, BUY EXECUTED, 22.07
# 2022-06-17, CLOSE LONG , 22.67
# 2022-06-17, SELL CREATE , 22.67
# 2022-06-21, SELL EXECUTED, 23.82
# 2022-06-21, SELL EXECUTED, 23.82
# 2022-06-21, CLOSE SHORT , 24.38
# 2022-06-21, BUY CREATE, 24.38
# 2022-06-22, BUY EXECUTED, 23.71
# 2022-06-22, BUY EXECUTED, 23.71
# 2022-06-22, CLOSE SHORT , 24.29
# 2022-06-22, BUY CREATE, 24.29
# 2022-06-23, SELL EXECUTED, 24.94
# 2022-06-23, BUY EXECUTED, 24.94
# 2022-06-23, CLOSE SHORT , 25.33
# 2022-06-23, BUY CREATE, 25.33
# 2022-06-24, SELL EXECUTED, 26.11
# 2022-06-24, BUY EXECUTED, 26.11
# 2022-06-24, CLOSE LONG , 27.98
# 2022-06-24, SELL CREATE , 27.98
# 2022-06-27, SELL EXECUTED, 28.35
# 2022-06-27, SELL EXECUTED, 28.35
# 2022-06-27, CLOSE SHORT , 27.32
# 2022-06-27, BUY CREATE, 27.32
# 2022-06-28, BUY EXECUTED, 27.46
# 2022-06-28, BUY EXECUTED, 27.46
# 2022-06-28, CLOSE LONG , 24.83
# 2022-06-28, SELL CREATE , 24.83
# 2022-06-29, SELL EXECUTED, 24.78
# 2022-06-29, SELL EXECUTED, 24.78
# 2022-06-29, CLOSE SHORT , 24.88
# 2022-06-29, BUY CREATE, 24.88
# 2022-06-30, BUY EXECUTED, 24.06
# 2022-06-30, BUY EXECUTED, 24.06
# 2022-06-30, CLOSE LONG , 24.00
# 2022-06-30, SELL CREATE , 24.00
# 2022-07-01, SELL EXECUTED, 23.60
# 2022-07-01, SELL EXECUTED, 23.60
# 2022-07-01, CLOSE SHORT , 24.39
# 2022-07-01, BUY CREATE, 24.39
# 2022-07-05, BUY EXECUTED, 23.41
# 2022-07-05, BUY EXECUTED, 23.41
# 2022-07-05, CLOSE LONG , 25.65
# 2022-07-05, SELL CREATE , 25.65
# 2022-07-06, SELL EXECUTED, 25.77
# 2022-07-06, SELL EXECUTED, 25.77
# 2022-07-06, CLOSE SHORT , 26.14
# 2022-07-06, BUY CREATE, 26.14
# 2022-07-07, BUY EXECUTED, 26.38
# 2022-07-07, BUY EXECUTED, 26.38
# 2022-07-07, CLOSE SHORT , 27.76
# 2022-07-07, BUY CREATE, 27.76
# 2022-07-08, SELL EXECUTED, 26.99
# 2022-07-08, BUY EXECUTED, 26.99
# 2022-07-08, CLOSE SHORT , 27.89
# 2022-07-08, BUY CREATE, 27.89
# 2022-07-11, SELL EXECUTED, 27.20
# 2022-07-11, BUY EXECUTED, 27.20
# 2022-07-11, CLOSE LONG , 26.11
# 2022-07-11, SELL CREATE , 26.11
# 2022-07-12, SELL EXECUTED, 26.44
# 2022-07-12, SELL EXECUTED, 26.44
# 2022-07-12, CLOSE LONG , 25.35
# 2022-07-12, SELL CREATE , 25.35
# 2022-07-13, BUY EXECUTED, 23.84
# 2022-07-13, SELL EXECUTED, 23.84
# 2022-07-13, CLOSE LONG , 25.19
# 2022-07-13, SELL CREATE , 25.19
# 2022-07-14, BUY EXECUTED, 24.47
# 2022-07-14, SELL EXECUTED, 24.47
# 2022-07-14, CLOSE LONG , 25.45
# 2022-07-14, SELL CREATE , 25.45
# 2022-07-15, BUY EXECUTED, 26.27
# 2022-07-15, SELL EXECUTED, 26.27
# 2022-07-15, CLOSE SHORT , 26.79
# 2022-07-15, BUY CREATE, 26.79
# 2022-07-18, BUY EXECUTED, 27.61
# 2022-07-18, BUY EXECUTED, 27.61
# 2022-07-18, CLOSE SHORT , 26.17
# 2022-07-18, BUY CREATE, 26.17
# 2022-07-19, SELL EXECUTED, 27.15
# 2022-07-19, BUY EXECUTED, 27.15
# 2022-07-19, CLOSE SHORT , 28.46
# 2022-07-19, BUY CREATE, 28.46
# 2022-07-20, SELL EXECUTED, 28.66
# 2022-07-20, BUY EXECUTED, 28.66
# 2022-07-20, CLOSE LONG , 29.89
# 2022-07-20, SELL CREATE , 29.89
# 2022-07-21, SELL EXECUTED, 30.01
# 2022-07-21, SELL EXECUTED, 30.01
# 2022-07-21, CLOSE SHORT , 31.16
# 2022-07-21, BUY CREATE, 31.16
# 2022-07-22, BUY EXECUTED, 30.88
# 2022-07-22, BUY EXECUTED, 30.88
# 2022-07-22, CLOSE SHORT , 29.53
# 2022-07-22, BUY CREATE, 29.53
# 2022-07-25, SELL EXECUTED, 29.53
# 2022-07-25, BUY EXECUTED, 29.53
# 2022-07-25, CLOSE LONG , 29.09
# 2022-07-25, SELL CREATE , 29.09
# 2022-07-26, SELL EXECUTED, 28.49
# 2022-07-26, SELL EXECUTED, 28.49
# 2022-07-26, CLOSE SHORT , 27.33
# 2022-07-26, BUY CREATE, 27.33
# 2022-07-27, BUY EXECUTED, 28.60
# 2022-07-27, BUY EXECUTED, 28.60
# 2022-07-27, CLOSE LONG , 30.74
# 2022-07-27, SELL CREATE , 30.74
# 2022-07-28, SELL EXECUTED, 30.68
# 2022-07-28, SELL EXECUTED, 30.68
# 2022-07-28, CLOSE LONG , 31.62
# 2022-07-28, SELL CREATE , 31.62
# 2022-07-29, BUY EXECUTED, 32.13
# 2022-07-29, SELL EXECUTED, 32.13
# 2022-08-02, CLOSE SHORT , 33.00
# 2022-08-02, BUY CREATE, 33.00
# 2022-08-03, BUY EXECUTED, 33.55
# 2022-08-03, BUY EXECUTED, 33.55
# 2022-08-03, CLOSE LONG , 35.64
# 2022-08-03, SELL CREATE , 35.64
# 2022-08-04, SELL EXECUTED, 35.69
# 2022-08-04, SELL EXECUTED, 35.69
# 2022-08-04, CLOSE LONG , 36.15
# 2022-08-04, SELL CREATE , 36.15
# 2022-08-05, BUY EXECUTED, 34.43
# 2022-08-05, SELL EXECUTED, 34.43
# 2022-08-05, CLOSE LONG , 35.29
# 2022-08-05, SELL CREATE , 35.29
# 2022-08-08, BUY EXECUTED, 35.60
# 2022-08-08, SELL EXECUTED, 35.60
# 2022-08-09, CLOSE SHORT , 33.73
# 2022-08-09, BUY CREATE, 33.73
# 2022-08-10, BUY EXECUTED, 36.14
# 2022-08-10, BUY EXECUTED, 36.14
# 2022-08-12, CLOSE SHORT , 37.98
# 2022-08-12, BUY CREATE, 37.98
# 2022-08-15, SELL EXECUTED, 37.65
# 2022-08-15, BUY EXECUTED, 37.65
# 2022-08-15, CLOSE LONG , 38.89
# 2022-08-15, SELL CREATE , 38.89
# 2022-08-16, SELL EXECUTED, 38.56
# 2022-08-16, SELL EXECUTED, 38.56
# 2022-08-16, CLOSE SHORT , 38.64
# 2022-08-16, BUY CREATE, 38.64
# 2022-08-17, BUY EXECUTED, 37.51
# 2022-08-17, BUY EXECUTED, 37.51
# 2022-08-17, CLOSE SHORT , 37.30
# 2022-08-17, BUY CREATE, 37.30
# 2022-08-18, SELL EXECUTED, 37.26
# 2022-08-18, BUY EXECUTED, 37.26
# 2022-08-19, CLOSE LONG , 35.35
# 2022-08-19, SELL CREATE , 35.35
# 2022-08-22, SELL EXECUTED, 33.89
# 2022-08-22, SELL EXECUTED, 33.89
# 2022-08-23, CLOSE SHORT , 32.46
# 2022-08-23, BUY CREATE, 32.46
# 2022-08-24, BUY EXECUTED, 32.30
# 2022-08-24, BUY EXECUTED, 32.30
# 2022-08-24, CLOSE SHORT , 32.71
# 2022-08-24, BUY CREATE, 32.71
# 2022-08-25, SELL EXECUTED, 33.28
# 2022-08-25, BUY EXECUTED, 33.28
# 2022-08-25, CLOSE LONG , 34.43
# 2022-08-25, SELL CREATE , 34.43
# 2022-08-26, SELL EXECUTED, 34.35
# 2022-08-26, SELL EXECUTED, 34.35
# 2022-08-26, CLOSE LONG , 30.24
# 2022-08-26, SELL CREATE , 30.24
# 2022-08-29, BUY EXECUTED, 29.35
# 2022-08-29, SELL EXECUTED, 29.35
# 2022-08-29, CLOSE SHORT , 29.31
# 2022-08-29, BUY CREATE, 29.31
# 2022-08-30, BUY EXECUTED, 29.79
# 2022-08-30, BUY EXECUTED, 29.79
# 2022-08-30, CLOSE SHORT , 28.33
# 2022-08-30, BUY CREATE, 28.33
# 2022-08-31, SELL EXECUTED, 29.16
# 2022-08-31, BUY EXECUTED, 29.16
# 2022-08-31, CLOSE SHORT , 27.81
# 2022-08-31, BUY CREATE, 27.81
# 2022-09-01, SELL EXECUTED, 27.08
# 2022-09-01, BUY EXECUTED, 27.08
# 2022-09-01, CLOSE LONG , 27.84
# 2022-09-01, SELL CREATE , 27.84
# 2022-09-02, SELL EXECUTED, 28.64
# 2022-09-02, SELL EXECUTED, 28.64
# 2022-09-02, CLOSE SHORT , 26.68
# 2022-09-02, BUY CREATE, 26.68
# 2022-09-06, BUY EXECUTED, 26.76
# 2022-09-06, BUY EXECUTED, 26.76
# 2022-09-06, CLOSE LONG , 26.07
# 2022-09-06, SELL CREATE , 26.07
# 2022-09-07, SELL EXECUTED, 26.18
# 2022-09-07, SELL EXECUTED, 26.18
# 2022-09-07, CLOSE LONG , 27.61
# 2022-09-07, SELL CREATE , 27.61
# 2022-09-08, BUY EXECUTED, 27.03
# 2022-09-08, SELL EXECUTED, 27.03
# 2022-09-08, CLOSE SHORT , 28.06
# 2022-09-08, BUY CREATE, 28.06
# 2022-09-09, BUY EXECUTED, 28.68
# 2022-09-09, BUY EXECUTED, 28.68
# 2022-09-09, CLOSE LONG , 29.84
# 2022-09-09, SELL CREATE , 29.84
# 2022-09-12, SELL EXECUTED, 30.30
# 2022-09-12, SELL EXECUTED, 30.30
# 2022-09-12, CLOSE SHORT , 30.93
# 2022-09-12, BUY CREATE, 30.93
# 2022-09-13, BUY EXECUTED, 28.24
# 2022-09-13, BUY EXECUTED, 28.24
# 2022-09-13, CLOSE LONG , 25.84
# 2022-09-13, SELL CREATE , 25.84
# 2022-09-14, SELL EXECUTED, 26.13
# 2022-09-14, SELL EXECUTED, 26.13
# 2022-09-15, CLOSE SHORT , 25.09
# 2022-09-15, BUY CREATE, 25.09
# 2022-09-16, BUY EXECUTED, 24.21
# 2022-09-16, BUY EXECUTED, 24.21
# 2022-09-16, CLOSE SHORT , 24.60
# 2022-09-16, BUY CREATE, 24.60
# 2022-09-19, SELL EXECUTED, 23.94
# 2022-09-19, BUY EXECUTED, 23.94
# 2022-09-19, CLOSE SHORT , 25.19
# 2022-09-19, BUY CREATE, 25.19
# 2022-09-20, SELL EXECUTED, 24.53
# 2022-09-20, BUY EXECUTED, 24.53
# 2022-09-20, CLOSE SHORT , 24.59
# 2022-09-20, BUY CREATE, 24.59
# 2022-09-21, SELL EXECUTED, 24.81
# 2022-09-21, BUY EXECUTED, 24.81
# 2022-09-21, CLOSE LONG , 23.24
# 2022-09-21, SELL CREATE , 23.24
# 2022-09-22, SELL EXECUTED, 22.85
# 2022-09-22, SELL EXECUTED, 22.85
# 2022-09-22, CLOSE LONG , 22.38
# 2022-09-22, SELL CREATE , 22.38
# 2022-09-23, BUY EXECUTED, 21.80
# 2022-09-23, SELL EXECUTED, 21.80
# 2022-09-23, CLOSE SHORT , 21.31
# 2022-09-23, BUY CREATE, 21.31
# 2022-09-26, BUY EXECUTED, 21.16
# 2022-09-26, BUY EXECUTED, 21.16
# 2022-09-26, CLOSE SHORT , 21.02
# 2022-09-26, BUY CREATE, 21.02
# 2022-09-27, SELL EXECUTED, 21.82
# 2022-09-27, BUY EXECUTED, 21.82
# 2022-09-27, CLOSE SHORT , 21.04
# 2022-09-27, BUY CREATE, 21.04
# 2022-09-28, SELL EXECUTED, 21.03
# 2022-09-28, BUY EXECUTED, 21.03
# 2022-09-28, CLOSE LONG , 22.27
# 2022-09-28, SELL CREATE , 22.27
# 2022-09-29, SELL EXECUTED, 21.31
# 2022-09-29, SELL EXECUTED, 21.31
# 2022-09-29, CLOSE LONG , 20.39
# 2022-09-29, SELL CREATE , 20.39
# Final Portfolio Value: 2426.60
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="300">

# %%
from hyperopt import tpe, hp, fmin
import numpy as np
def objective(params):
    x, y = params['xa'], params['ya']
    return np.sin(np.sqrt(x**2 + y**2))
# x = np.linspace(-6, 6, 30)
# y = np.linspace(-6, 6, 30)
z = objective({'xa': x, 'ya': y})
space = {
    'xa': hp.uniform('x1', -6, 6),
    'ya': hp.uniform('y1', -6, 6)
}
best = fmin(
    fn=objective, # Objective Function to optimize
    space=space, # Hyperparameter's Search Space
    algo=tpe.suggest, # Optimization algorithm (representative TPE)
    max_evals=1000 # Number of optimization attempts
)
print(best)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 from hyperopt import tpe, hp, fmin,fmax
#       2 import numpy as np
#       3 def objective(params):
#
# ImportError: cannot import name 'fmax' from 'hyperopt' (/home/gs/.local/share/virtualenvs/gs-KL75tqvG/lib/python3.8/site-packages/hyperopt/__init__.py)
